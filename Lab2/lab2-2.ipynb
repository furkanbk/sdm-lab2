# %%
import pandas as pd

# %%
from rdflib import Graph, Literal, RDF, URIRef
from rdflib.namespace import XSD

# Creating an RDF graph
g = Graph()

# Namespace definitions
base_uri = "http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#"
ns = URIRef(base_uri)

# Custom namespaces for properties and classes
PAPER = URIRef(base_uri + "Paper")
AUTHOR = URIRef(base_uri + "Author")
YEAR = URIRef(base_uri + "Year")

# %% [markdown]
# Creating from paper_details.csv to paper_details.ttl

# %%
import csv

# Assuming the CSV file is loaded as `paper_details.csv`
with open('data/papers_details.csv', newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        # Create a URI for each paper based on its ID
        paper_uri = URIRef(ns + row['paperId'])
        
        # Add RDF types and literals for properties
        g.add((paper_uri, RDF.type, PAPER))
        g.add((paper_uri, URIRef(ns + "title"), Literal(row['title'], datatype=XSD.string)))
        g.add((paper_uri, URIRef(ns + "abstract"), Literal(row['abstract'], datatype=XSD.string)))
        g.add((paper_uri, URIRef(ns + "year"), Literal(row['year'], datatype=XSD.gYear)))
        g.add((paper_uri, URIRef(ns + "keywords"), Literal(row['keywords'], datatype=XSD.string)))
        g.add((paper_uri, URIRef(ns + "doi"), Literal(row['doi'], datatype=XSD.string)))

        # Additional properties would be added here based on availability

# Serialize graph to Turtle format and save
g.serialize(destination='turtle/papers_details.ttl', format='turtle')
print("Serialized and saved the Turtle file.")
# Out:
# Serialized and saved the Turtle file.

# %% [markdown]
# Testing paper_details.ttl

# %%
from rdflib import Graph, URIRef

# Load the Turtle file into an RDFLib graph
g = Graph()
g.parse("turtle/papers_details.ttl", format="turtle")

# Namespace of your ontology
base_uri = "http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#"
PAPER = URIRef(base_uri + "Paper")

# Test 1: Check if papers are loaded correctly
papers = list(g.subjects(RDF.type, PAPER))
print(f"Total papers loaded: {len(papers)}")

# Test 2: Print titles and years of papers to verify data
for paper in papers:
    title = g.value(paper, URIRef(base_uri + "title"))
    year = g.value(paper, URIRef(base_uri + "year"))
    print(f"Title: {title}, Year: {year}")

# Optional: Run a SPARQL query to retrieve specific data
query = """
SELECT ?title ?year WHERE {
    # ?paper a <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper>.
    # ?paper <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#title> ?title.
    # ?paper <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#year> ?year.
}
ORDER BY ?year
LIMIT 10
"""
for row in g.query(query):
    print(f"Title: {row.title}, Year: {row.year}")
# Out:
# Total papers loaded: 174
# Title: Signature File Methods for Indexing Object-Oriented Database Systems, Year: 1992
# Title: Enhance Student Learning with PowerPoint Games: Using Twenty Questions to Promote Active Learning in Managerial Accounting, Year: 2011
# Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling, Year: 2021
# Title: O-Minimal Hybrid Reachability Games, Year: 2009
# Title: Advanced Techniques for Content-Based Management of Multimedia Databases, Year: 2005
# Title: Computational Trust Models and Machine Learning, Year: 2014
# Title: Combining Machine Learning with Knowledge Engineering to detect Fake News in Social Networks - A Survey, Year: 2022
# Title: Applying Machine Learning Techniques to Improve Linux Process Scheduling, Year: 2005
# Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students, Year: 2019
# Title: Forecasting Stock Market Prices Using Machine Learning and Deep Learning Models: A Systematic Review, Performance Analysis and Discussion of Implications, Year: 2023
# Title: An Introduction to Relational Database Theory, Year: 2002
# Title: Emergent Conventions in Evolutionary Games, Year: 2008
# Title: Machine Learning for Predicting Cognitive Diseases: Methods, Data Sources and Risk Factors, Year: 2018
# Title: Photorealistic Monocular Gaze Redirection Using Machine Learning, Year: 2018
# Title: ffi cient Controller Synthesis for Consumption Games with Multiple Resource Types, Year: 2012
# Title: Evolving Applications of Artificial Intelligence and Machine Learning in Infectious Diseases Testing, Year: 2021
# Title: Selected papers from the International Workshop on The World Wide Web and Databases, Year: 1998
# Title: Teaching Responsible Conduct of Research Through an Interactive Storytelling Game, Year: 2020
# Title: The Maxmin of Recursive Games with Incomplete Information on one Side, Year: 2000
# Title: The Influence of Social Value Orientation on Information Processing in repeated Voluntary Contribution Mechanism (VCM) Games: An Eye-tracking Analysis, Year: 2012
# Title: miRLocator: Machine Learning-Based Prediction of Mature MicroRNAs within Plant Pre-miRNA Sequences, Year: 2015
# Title: Classification of Children’s Sitting Postures Using Machine Learning Algorithms, Year: 2018
# Title: Season-Based Occupancy Prediction in Residential Buildings Using Machine Learning Models, Year: 2021
# Title: A Game-Theoretic Analysis of the Off-Switch Game, Year: 2017
# Title: 2005 Special Issue: Beyond emotion archetypes: Databases for emotion modelling using neural networks, Year: 2005
# Title: The Game of Triangles, Year: 2019
# Title: Stopping Games - Recent Results, Year: 2005
# Title: Relational Database to RDF Mapping Patterns, Year: 2012
# Title: Game Play: What Does It Mean for Pedagogy to Think Like a Game Developer?, Year: 2014
# Title: Database technology in health care, Year: 2005
# Title: Greedy and Linear Ensembles of Machine Learning Methods Outperform Single Approaches for QSPR Regression Problems, Year: 2015
# Title: Machine Learning-Based Classification of Human Behaviors and Falls in Restroom via Dual Doppler Radar Measurements, Year: 2022
# Title: iShare: Blockchain-Based Privacy-Aware Multi-Agent Information Sharing Games for Cybersecurity, Year: 2018
# Title: Methods for Forecasting Nonlinear Non-stationary Processes in Machine Learning, Year: 2020
# Title: Linear-Quadratic Mean Field Stackelberg Games with State and Control Delays, Year: 2017
# Title: The Impact of Monitoring in Infinitely Repeated Games: Perfect, Public, and Private, Year: 2015
# Title: This Uprising of Mine: Game Conventions, Cultural Memory and Civilian Experience of War in Polish Games, Year: 2016
# Title: The Paradigm of Computing with Words in Intelligent Database Querying, Year: 1999
# Title: Computer-Generated Music for Tabletop Role-Playing Games, Year: 2020
# Title: AudioInSpace: Exploring the Creative Fusion of Generative Audio, Visuals and Gameplay, Year: 2015
# Title: Player Goal Recognition in Open-World Digital Games with Long Short-Term Memory Networks, Year: 2016
# Title: Fundamental Tradeoffs and Constrained Coalitional Games in Autonomic Wireless Networks, Year: 2007
# Title: Game Design Patterns for Collaborative Player Interactions, Year: 2014
# Title: Database aesthetics, Year: 2000
# Title: Immersive Multiplayer Games With Tangible and Physical Interaction, Year: 2010
# Title: Game-theoretic cooperativity in networks of self-interested units, Year: 1987
# Title: A Game-Theoretic Framework for Optimum Decision Fusion in the Presence of Byzantines, Year: 2015
# Title: Waiting for Something to Happen: Narratives, Interactivity and Agency and the Video Game Cut-scene, Year: 2007
# Title: Predicting Cyber Risks through National Vulnerability Database, Year: 2015
# Title: Using Online Computer Games in the ELT Classroom: A Case Study, Year: 2017
# Title: A Cooperative Game Framework for QoS Guided Job Allocation Schemes in Grids, Year: 2008
# Title: Computer Game Use and Television Viewing Increased Risk for Overweight among Low Activity Girls: Fourth Thai National Health Examination Survey 2008-2009, Year: 2014
# Title: Capture Database through Symbolization, Recognition and Generation of Motion Patterns, Year: 2007
# Title: Non-Cooperative Multicast and Facility Location Games, Year: 2006
# Title: Teaching Engineering Ethics using BLOCKS Game, Year: 2013
# Title: Demand Interprocedural Program Analysis Using Logic Databases, Year: 1993
# Title: Productive Gaming and the Case for Historiographic Game-Play, Year: 2009
# Title: The Effectiveness of Games as Assignments in an Introductory Programming Course, Year: 2006
# Title: Design Your Own Games and Activities: Thiagi's Templates for Performance Improvement, Year: 2003
# Title: Database Forensic Investigation Based on Table Relationship Analysis Techniques, Year: 2009
# Title: Evolution of Games Towards The Discovery of Noble Uncertainty, Year: 2019
# Title: Game-based Abstraction for Markov Decision Processes, Year: 2006
# Title: Game theory for cyber security, Year: 2010
# Title: BCI Promises in Emotional Involvement in Music and Games, Year: 2014
# Title: Attention-LSTM-Attention Model for Speech Emotion Recognition and Analysis of IEMOCAP Database, Year: 2020
# Title: Automated Ranking of Database Query Results, Year: 2003
# Title: MarioQA: Answering Questions by Watching Gameplay Videos, Year: 2016
# Title: Cybersickness Among Gamers: An Online Survey, Year: 2019
# Title: Automating Physical Database Design in a Parallel Database, Year: 2002
# Title: Querying Encrypted Graph Databases, Year: 2018
# Title: Testing Spatial Data Deliverance in SQL and NoSQL Database Using NodeJS Fullstack Web App, Year: 2018
# Title: Ontology searching and browsing at the Rat Genome Database, Year: 2012
# Title: Coordination in CIM:Bringing Database Functionality to Application Systems, Year: 1998
# Title: Tripartite ATP-Independent Periplasmic Transporters: Application of a Relational Database for Genome-Wide Analysis of Transporter Gene Frequency and Organization, Year: 2007
# Title: Databases and ontologies Advance Access publication March 7, 2013 PLncDB: plant long non-coding RNA database, Year: 2013
# Title: Experimenting with the Archive: STS-ers As Analysts and Co-constructors of Databases and Other Archival Forms, Year: 2010
# Title: A Computer Games Software Factory and Edutainment Platform for Microsoft .NET, Year: 2007
# Title: STREETS: Game-Theoretic Traffic Patrolling with Exploration and Exploitation, Year: 2014
# Title: Multi-Pursuer Multi-Evader Pursuit-Evasion Games with Jamming Confrontation, Year: 2007
# Title: The impact of AlphaFold Protein Structure Database on the fields of life sciences, Year: 2022
# Title: Is This a Game or a Learning Moment, Year: 2006
# Title: Understanding Interpersonal Function in Psychiatric Illness Through Multiplayer Economic Games, Year: 2012
# Title: OntoDB: It Is Time to Embed Your Domain Ontology in Your Database, Year: 2007
# Title: Security Metrics Based on Attack Graphs for the Olympic Games Scenario, Year: 2014
# Title: From Parity and Payoff Games to Linear Programming, Year: 2009
# Title: Transaction Models for Advanced Database Applications, Year: 1991
# Title: Strategy Grafting in Extensive Games, Year: 2009
# Title: Game creativity analysis using neural networks, Year: 2009
# Title: Game Theory Based Optimization of Security Configuration, Year: 2007
# Title: Price-Based Resource Allocation for Spectrum-Sharing Femtocell Networks: A Stackelberg Game Approach, Year: 2011
# Title: Numerical Solutions for Stochastic Differential Games With Regime Switching, Year: 2008
# Title: Terrain Reasoning for 3 D Action Games, Year: 2001
# Title: Bendtroller:: An Exploration of In-Game Action Mappings with a Deformable Game Controller, Year: 2017
# Title: Comparison of Individualized Computer Game Reinforcement versus Peer-interactive Board Game Reinforcement on Retention of Nutrition Label Knowledge, Year: 2000
# Title: Mobile Game-Based Science Learning, Year: 2006
# Title: EEG Databases in Research and Clinical Practice: Current Status and Future Directions, Year: 2005
# Title: Creating a Business Process Diagram and Database Queries to Detect Billing Errors and Analyze Calling Patterns for Cell Phone Service, Year: 2007
# Title: Bounds on the Price of stability of Undirected Network Design Games with Three Players, Year: 2011
# Title: Database Management: Concepts, Design, and Practice, Year: 1990
# Title: The Open and the Closed: Games of Emergence and Games of Progression, Year: 2002
# Title: Integrating Locking and Optimistic Concurrency Control in Distributed Database Systems, Year: 1986
# Title: On Game-Theoretic Network Security Provisioning, Year: 2013
# Title: Collaborate and Share: An Experimental Study of the Effects of Task and Reward Interdependencies in Online Games, Year: 2007
# Title: Intrapartum Fetal Heart Rate Classification: Cross-Database Evaluation, Year: 2016
# Title: A Classification and Comparison of Main Memory Database Recovery Techniques, Year: 1987
# Title: A Tool for Storing OWL Using Database Technology, Year: 2005
# Title: Mancala Games -- Topics in Artificial Intelligence and Mathematics, Year: 2002
# Title: Efficient 3D Database Screening for Novel HIV-1 IN Inhibitors, Year: 2004
# Title: Causality and Explanations in Databases, Year: 2014
# Title: Zero-Sum Repeated Games: Recent Advances and New Links with Differential Games, Year: 2011
# Title: The Epistemic Logic of IF Games, Year: 2003
# Title: Private Read Update Write (PRUW) with Storage Constrained Databases, Year: 2022
# Title: A Survey of Game Theoretic Approaches to Modelling Decision-Making in Information Warfare Scenarios, Year: 2016
# Title: Review on Emotion Recognition Databases, Year: 2017
# Title: Database updates in logic programming, Year: 1988
# Title: A Model for the Evaluation of Educational Games for Teaching Software Engineering, Year: 2011
# Title: Analyzing the Factors that Influence Learning Experience through Game Based Learning using Visual Novel Game for Learning Pancasila, Year: 2019
# Title: Predicting Student Self-regulation Strategies in Game-Based Learning Environments, Year: 2012
# Title: Design and Computer Simulated User Scenarios: Exploring Real-Time 3D Game Engines and Simulation in the Maritime Sector, Year: 2015
# Title: Resisting Collusion by Game in Culture Web, Year: 2011
# Title: Database resources of the National Center for Biotechnology Information: update, Year: 2004
# Title: Nearest Neighbor Search:: A Database Perspective, Year: 2004
# Title: Learning Games as a Platform for Simulated Science Practice, Year: 2005
# Title: Simulation Games and Learning, Year: 2007
# Title: View Integration in Conceptual Database Design : Problems, Approaches and Solutions, Year: 2006
# Title: Scalable Neural Networks for Board Games, Year: 2009
# Title: Polish Emotional Speech Database - Recording and Preliminary Validation, Year: 2009
# Title: Database Encryption - How to Balance Security with Performance, Year: 2005
# Title: Ludoliteracy: Defining, Understanding, and Supporting Games Education, Year: 2010
# Title: Affective Design Patterns in Computer Games. Scrollrunner Case Study, Year: 2017
# Title: Model Checking in Multiplayer Games Development, Year: 2017
# Title: Querying Relational Databases with RDQL, Year: 2005
# Title: Educational Applications of a Networked Communal Database, Year: 1992
# Title: Communities of Play: Emergent Cultures in Multiplayer Games and Virtual Worlds, Year: 2012
# Title: Mining Type Schemes in Databases, Year: 1996
# Title: 10 Key Principles for Designing Video Games for Foreign Language Learning, Year: 2009
# Title: Visualization and Virtual Screening of the Chemical Universe Database GDB-17, Year: 2013
# Title: Communitywide Database Designs for Tracking Innovation Impact: Comets, Stars and Nanobank, Year: 2011
# Title: Applying Game Design Elements in the Workplace, Year: 2015
# Title: Optimization of Detected Deadlock Views of Distributed Database, Year: 2010
# Title: Natural language Interface for Database: A Brief review, Year: 2011
# Title: A First Course on Zero-Sum Repeated Games by Sylvain Sorin, Year: 2003
# Title: An Animated Introduction to Relational Databases for Many Majors, Year: 2015
# Title: Manipulating Spatial Data in Constraint Databases, Year: 1997
# Title: On the Robustness of the Extension of the One-Third Law of Evolution to the Multi-Player Game, Year: 2011
# Title: Measuring the Size of Large No-Limit Poker Games, Year: 2013
# Title: Mean-Field-Type Games with Jump and Regime Switching, Year: 2020
# Title: Designing and Recording an Emotional Speech Database for Corpus Based Synthesis in Basque, Year: 2006
# Title: A Shapley Value Representation of Potential Games, Year: 2000
# Title: Eye Gaze Assistance for a Game-Like Interactive Task, Year: 2008
# Title: A Strategy for Database Interoperation, Year: 1995
# Title: An Indexing and Retrieval Mechanism for Complex Similarity Queries in Image Databases, Year: 1999
# Title: Collection and Exploration of Large Data Monitoring Sets Using Bitmap Databases, Year: 2010
# Title: Design-by-Analogy: Exploring for Analogical Inspiration With Behavior, Material, and Component-Based Structural Representation of Patent Databases, Year: 2019
# Title: The PIR-International Protein Sequence Database., Year: 1996
# Title: A UIMA Database Interface for Managing NLP-related Text Annotations, Year: 2018
# Title: The Burkholderia Genome Database: facilitating flexible queries and comparative analyses, Year: 2008
# Title: Potential of Graph Databases in Representing and Enriching Standardized Geodata, Year: 2016
# Title: Database of Piano Chords - An Engineering View of Harmony, Year: 2013
# Title: Subjective Quality Assessment for Wireless Image Communication : The Wireless Imaging Quality Database, Year: 2010
# Title: Approximations in Database Systems, Year: 2003
# Title: A Comprehensive Guide Through the Italian Database Research Over the Last 25 Years, Year: 2018
# Title: A Database of Vocal Tract Resonance Trajectories for Research in Speech Processing, Year: 2006
# Title: CoDEL - A Relationally Complete Language for Database Evolution, Year: 2015
# Title: Graph Databases in Molecular Biology, Year: 2018
# Title: Parallel Evaluation of Hierarchical Image Databases, Year: 1995
# Title: Cryptographic Protection of Databases and Software, Year: 1989
# Title: A Practical Guide to Using Glycomics Databases, Year: 2017
# Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments, Year: 2020
# Title: Database Migration from Structured Database to non-Structured Database, Year: 2015
# Title: Databases in Grid Applications: Locality and Distribution, Year: 2005
# Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract), Year: 1978
# Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU, Year: 2010
# Title: An XML-Based Database for Knowledge Discovery, Year: 2006
# Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract), Year: 1978
# Title: Integrating Locking and Optimistic Concurrency Control in Distributed Database Systems, Year: 1986
# Title: Game-theoretic cooperativity in networks of self-interested units, Year: 1987
# Title: A Classification and Comparison of Main Memory Database Recovery Techniques, Year: 1987
# Title: Database updates in logic programming, Year: 1988
# Title: Cryptographic Protection of Databases and Software, Year: 1989
# Title: Database Management: Concepts, Design, and Practice, Year: 1990
# Title: Transaction Models for Advanced Database Applications, Year: 1991
# Title: Signature File Methods for Indexing Object-Oriented Database Systems, Year: 1992
# Title: Educational Applications of a Networked Communal Database, Year: 1992

# %%
def escape_literal(text):
    """ Escapes quotes and controls characters in a text string for Turtle output. """
    if pd.isna(text):
        return ""
    # Escape backslashes first, then quotes, and replace newlines and carriage returns
    text = text.replace('\\', '\\\\').replace('"', '\\"').replace('\n', ' ').replace('\r', ' ')
    return text

# Load the CSV file
df = pd.read_csv('data/papers_details_enriched.csv')

# Define the base namespace for your papers
base_ns = "http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#"

# Open a file to write the Turtle content
with open('turtle/papers_details_enriched.ttl', 'w') as ttl_file:
    ttl_file.write('@prefix ns1: <{}> .\n'.format(base_ns))
    ttl_file.write('@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n\n')
    
    # Iterate over the DataFrame rows
    for index, row in df.iterrows():
        paper_id = 'Paper_' + str(row['paperId'])
        title = escape_literal(row['title'])
        abstract = escape_literal(row['abstract'])
        year = str(int(row['year'])) if pd.notna(row['year']) else ""
        keywords = escape_literal(row['keywords'])
        doi = escape_literal(row['doi'])

        # Create an entry for each paper with its details
        ttl_file.write('ns1:{} a ns1:Paper ;\n'.format(paper_id))
        ttl_file.write('    ns1:title "{}"^^xsd:string ;\n'.format(title))
        ttl_file.write('    ns1:abstract "{}"^^xsd:string ;\n'.format(abstract))
        ttl_file.write('    ns1:year "{}"^^xsd:gYear ;\n'.format(year))
        ttl_file.write('    ns1:keywords "{}"^^xsd:string ;\n'.format(keywords))
        ttl_file.write('    ns1:doi "{}"^^xsd:string .\n\n'.format(doi))

print("Turtle file has been created with sanitized literals.")
# Out:
# Turtle file has been created with sanitized literals.

# %%
import re

def escape_literals(input_line):
    # This pattern matches text between quotes
    pattern = re.compile(r'"(.*?)(?<!\\)"', re.DOTALL)
    
    def replace_func(match):
        # Replace internal quotes with escaped quotes and escape newlines within the string
        escaped_string = match.group(1).replace('"', '\\"').replace('\n', ' ')
        # Ensure we do not double escape already escaped quotes
        escaped_string = re.sub(r'\\\\"', r'\\"', escaped_string)
        return f"\"{escaped_string}\""
    
    return pattern.sub(replace_func, input_line)

input_file_path = 'turtle/papers_details_enriched.ttl'
output_file_path = 'papers_details_enriched_fixed.ttl'

with open(input_file_path, 'r', encoding='utf-8') as infile, open(output_file_path, 'w', encoding='utf-8') as outfile:
    for line in infile:
        corrected_line = escape_literals(line)
        outfile.write(corrected_line)

print(f"Corrected file written to {output_file_path}")
# Out:
# Corrected file written to papers_details_enriched_fixed.ttl

# %% [markdown]
# Converting authors.csv --> authors.ttl

# %%
import csv
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, FOAF

# Define the namespaces
ex = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")
schema = Namespace("http://schema.org/")

# Create a graph
g = Graph()

# Bind the namespaces
g.bind("ex", ex)
g.bind("foaf", FOAF)

# Function to add authors to the graph
def add_author(author_id, name, affiliation, email):
    author_uri = ex[f"Author_{author_id}"]
    g.add((author_uri, RDF.type, ex.Author))
    g.add((author_uri, FOAF.name, Literal(name)))
    g.add((author_uri, schema.email, Literal(email)))
    g.add((author_uri, ex.affiliated_with, Literal(affiliation)))

# Read from the CSV file
with open('data/authors.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        add_author(row['authorId'], row['name'], row['affiliations'], row['email'])

# Serialize the graph to Turtle format
g.serialize(destination='turtle/authors.ttl', format='turtle')
print("Conversion to Turtle completed.")
# Out:
# Conversion to Turtle completed.

# %%
import csv
import re

def clean_affiliation_name(name):
    # Remove unwanted characters and encode spaces
    return re.sub(r'[^a-zA-Z0-9\s]', '', name).replace(' ', '_')

# Open the CSV file and read it
with open('data/affiliations.csv', 'r', encoding='utf-8') as csv_file:
    reader = csv.DictReader(csv_file)
    affiliations = list(reader)

# Open the Turtle file for writing
with open('turtle/affiliations.ttl', 'w', encoding='utf-8') as ttl_file:
    ttl_file.write("@prefix ap: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#> .\n")
    ttl_file.write("@prefix foaf: <http://xmlns.com/foaf/0.1/> .\n")
    ttl_file.write("@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .\n")
    ttl_file.write("@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n")
    ttl_file.write("@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n\n")
    
    # Iterate through each row and write data in Turtle format
    for affiliation in affiliations:
        cleaned_name = clean_affiliation_name(affiliation['name'])
        uri = f"ap:Affiliation_{cleaned_name}"
        address = affiliation['address'].replace('\n', ', ')
        
        ttl_file.write(f"{uri} rdf:type ap:Affiliation .\n")
        ttl_file.write(f"{uri} ap:affiliation_name \"{affiliation['name']}\"^^xsd:string .\n")
        ttl_file.write(f"{uri} ap:type \"{affiliation['type']}\"^^xsd:string .\n")
        ttl_file.write(f"{uri} ap:address \"{address}\"^^xsd:string .\n")
        ttl_file.write(f"{uri} ap:affiliation_email \"{affiliation['email']}\"^^xsd:string .\n")
        ttl_file.write(f"{uri} ap:phone_number \"{affiliation['phone_number']}\"^^xsd:string .\n")
        ttl_file.write("\n")

# %%
import pandas as pd
import re

# Load the CSV file
df = pd.read_csv('data/affiliated_with.csv')

# Function to convert affiliation names to a safe IRI format
def affiliation_to_iri(name):
    # Remove or replace invalid characters for IRI
    name = re.sub(r'[^\w\s]', '', name)  # Removes any non-alphanumeric characters
    name = name.replace(' ', '_')  # Replace spaces with underscores
    return f'ex:Affiliation_{name}'

# Prefixes for the Turtle file
prefixes = """
@prefix ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .

"""

# Open a file to write the Turtle content
with open('turtle/affiliated_with.ttl', 'w') as ttl_file:
    ttl_file.write(prefixes)
    
    # Iterate through the DataFrame and write each Turtle statement
    for index, row in df.iterrows():
        author_iri = f"ex:Author_{row['authorId']}"
        affiliation_iri = affiliation_to_iri(row['affiliation'])
        ttl_file.write(f"{author_iri} ex:affiliated_with {affiliation_iri} .\n")

print("Turtle file has been created.")
# Out:
# Turtle file has been created.

# %%
# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")
FOAF = Namespace("http://xmlns.com/foaf/0.1/")

# Create a new graph
g = Graph()

# Bind prefixes
g.bind("ex", EX)
g.bind("foaf", FOAF)

# Read CSV data
import csv
with open('data/journals.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create a new journal resource
        journal = EX[f"Venue_{row['ss_venue_id']}"]
        
        # Add properties to the journal
        g.add((journal, RDF.type, EX.Journal))
        g.add((journal, EX.name, Literal(row['name'])))
        g.add((journal, EX.issn, Literal(row['issn'])))
        g.add((journal, FOAF.homepage, URIRef(row['url'])))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/journals.ttl', format='turtle')
# Out:
# <Graph identifier=N4bbbb15b1f0f4523aeb5435510d8e571 (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from rdflib import Graph, Literal, RDF, URIRef, Namespace

# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")
FOAF = Namespace("http://xmlns.com/foaf/0.1/")

# Create a new graph
g = Graph()

# Bind prefixes
g.bind("ex", EX)
g.bind("foaf", FOAF)

# Read CSV data
import csv
with open('data/journals_enriched.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create a new journal resource
        journal = EX[f"Venue_{row['ss_venue_id']}"]
        
        # Add properties to the journal
        g.add((journal, RDF.type, EX.Journal))
        g.add((journal, EX.name, Literal(row['name'])))
        g.add((journal, FOAF.homepage, URIRef(row['url'])))
        g.add((journal, EX.year, Literal(row['year'], datatype=rdflib.XSD.integer)))
        g.add((journal, EX.volume, Literal(row['volume'], datatype=rdflib.XSD.integer)))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/journals_enriched.ttl', format='turtle')
# Out:
# <Graph identifier=N6890fc8a675a40ce9450b71ecbb965dd (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from rdflib import Graph, Literal, RDF, URIRef, Namespace

# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")
FOAF = Namespace("http://xmlns.com/foaf/0.1/")

# Create a new graph
g = Graph()

# Bind prefixes
g.bind("ex", EX)
g.bind("foaf", FOAF)

# Read CSV data
import csv
with open('data/conferences.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create a new conference resource
        conference = EX[f"Venue_{row['ss_venue_id']}"]
        
        # Add properties to the conference
        g.add((conference, RDF.type, EX.Conference))
        g.add((conference, EX.name, Literal(row['name'])))
        if row['url']:  # Ensure there is a URL before adding
            g.add((conference, FOAF.homepage, URIRef(row['url'])))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/conferences.ttl', format='turtle')
# Out:
# <Graph identifier=N94d09215dd2d4d8280fe080a15bb569a (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from rdflib import Graph, Literal, RDF, URIRef, Namespace

# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")
FOAF = Namespace("http://xmlns.com/foaf/0.1/")

# Create a new graph
g = Graph()

# Bind prefixes
g.bind("ex", EX)
g.bind("foaf", FOAF)

# Read CSV data
import csv
with open('data/conferences_enriched.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create a new conference resource
        conference = EX[f"Venue_{row['ss_venue_id']}"]
        
        # Add properties to the conference
        g.add((conference, RDF.type, EX.Conference))
        g.add((conference, EX.name, Literal(row['name'])))
        if row['url']:  # Ensure there is a URL before adding
            g.add((conference, FOAF.homepage, URIRef(row['url'])))
        g.add((conference, EX.city, Literal(row['city'])))
        g.add((conference, EX.year, Literal(row['year'], datatype=rdflib.XSD.gYear)))
        g.add((conference, EX.edition, Literal(int(row['edition']))))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/conferences_enriched.ttl', format='turtle')
# Out:
# <Graph identifier=Nfcf1998e498c46a58d45c2c5eb659e4f (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from rdflib import Graph, Literal, RDF, URIRef, Namespace

# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")
XSD = Namespace("http://www.w3.org/2001/XMLSchema#")

# Create a new graph
g = Graph()

# Bind prefixes
g.bind("ex", EX)
g.bind("xsd", XSD)

# Read CSV data
import csv
with open('data/reviews.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create a new review resource
        review = EX[f"Review_{row['review_id']}"]
        
        # Add properties to the review
        g.add((review, RDF.type, EX.Review))
        g.add((review, EX.decision, Literal(row['decision'])))
        g.add((review, EX.date, Literal(row['date'], datatype=XSD.date)))
        g.add((review, EX.abstract, Literal(row['abstract'])))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/reviews.ttl', format='turtle')
# Out:
# <Graph identifier=N7fb03ed0004648a0aec08c57ad3dafcd (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from rdflib import Graph, RDF, URIRef, Namespace

# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")

# Create a new graph
g = Graph()

# Bind prefix
g.bind("ex", EX)

# Read CSV data
import csv
with open('data/written_by.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create relationships
        paper = EX[f"Paper_{row['paperId']}"]
        author = EX[f"Author_{row['authorId']}"]
        
        # Add "written by" relationship
        g.add((paper, EX.written_by, author))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/written_by.ttl', format='turtle')
# Out:
# <Graph identifier=N94c8bfe1fce849b3b7c0320f59ec115c (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from rdflib import Graph, RDF, URIRef, Namespace

# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")

# Create a new graph
g = Graph()

# Bind prefix
g.bind("ex", EX)

# Read CSV data
import csv
with open('data/written_by_enriched.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create relationships
        paper = EX[f"Paper_{row['paperId']}"]
        author = EX[f"Author_{row['authorId']}"]
        
        # Add "written by" relationship
        g.add((paper, EX.written_by, author))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/written_by_enriched.ttl', format='turtle')
# Out:
# <Graph identifier=N9bc635a65b13413ea01c8ad3e19d9cb1 (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from rdflib import Graph, RDF, URIRef, Namespace, Literal

# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")

# Create a new graph
g = Graph()

# Bind prefix
g.bind("ex", EX)

# Read CSV data
import csv
with open('data/citations.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create citation relationships
        citing_paper = EX[f"Paper_{row['paperId']}"]
        cited_paper = EX[f"Paper_{row['referenceId']}"]
        year = Literal(row['year'], datatype=rdflib.XSD.integer)
        
        # Add citation relationship
        g.add((citing_paper, EX.cites_to, cited_paper))
        g.add((citing_paper, EX.citation_year, year))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/citations.ttl', format='turtle')
# Out:
# <Graph identifier=N3abec3b8f8a747769fd95c6f8fee0078 (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from rdflib import Graph, RDF, URIRef, Namespace, Literal

# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")

# Create a new graph
g = Graph()

# Bind prefix
g.bind("ex", EX)

# Read CSV data
import csv
with open('data/published_in_enriched.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create URIs for paper and venue
        paper = EX[f"Paper_{row['paper_id']}"]
        venue = EX[f"Venue_{row['ss_venue_id']}"]
        year = Literal(row['year'], datatype=rdflib.XSD.integer)
        
        # Add triples to the graph
        g.add((paper, EX.published_in, venue))
        g.add((paper, EX.publish_year, year))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/published_in_enriched.ttl', format='turtle')
# Out:
# <Graph identifier=N5f343a08e5a446ebb260df5cd2fb716b (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from rdflib import Graph, RDF, URIRef, Namespace, Literal

# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")

# Create a new graph
g = Graph()

# Bind prefix
g.bind("ex", EX)

# Read CSV data
import csv
with open('data/published_in_enriched_v2.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create URIs for paper and venue
        paper = EX[f"Paper_{row['paper_id']}"]
        venue = EX[f"Venue_{row['ss_venue_id']}"]
        year = Literal(row['year'], datatype=rdflib.XSD.integer)
        
        # Add triples to the graph
        g.add((paper, EX.published_in, venue))
        g.add((paper, EX.publish_year, year))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/published_in_enriched_v2.ttl', format='turtle')
# Out:
# <Graph identifier=N1247b0c39c2f4a17be053eb56b484f14 (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from rdflib import Graph, RDF, URIRef, Namespace, Literal

# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")

# Create a new graph
g = Graph()

# Bind prefix
g.bind("ex", EX)

# Read CSV data
import csv
with open('data/published_in.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create URIs for paper and venue
        paper = EX[f"Paper_{row['paper_id']}"]
        venue = EX[f"Venue_{row['ss_venue_id']}"]
        
        # Add triples to the graph
        g.add((paper, EX.published_in, venue))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/published_in.ttl', format='turtle')
# Out:
# <Graph identifier=Nce47b63314b84dcba7bdee31a8dee9d5 (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from rdflib import Graph, RDF, URIRef, Namespace, Literal

# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")

# Create a new graph
g = Graph()

# Bind prefix
g.bind("ex", EX)

# Read CSV data
import csv
with open('data/reviewed_by.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create URIs for review and author
        review = EX[f"Review_{row['review_id']}"]
        author = EX[f"Author_{row['author_id']}"]
        
        # Add triples to the graph
        g.add((review, EX.reviewed_by, author))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/reviewed_by.ttl', format='turtle')
# Out:
# <Graph identifier=N46113661bc4e4ff6af112b5c62c94e77 (<class 'rdflib.graph.Graph'>)>

# %%
# Define namespaces
EX = Namespace("http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#")

# Create a new graph
g = Graph()

# Bind prefix
g.bind("ex", EX)

# Read CSV data
import csv
with open('data/review_on.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create URIs for review and paper
        review = EX[f"Review_{row['review_id']}"]
        paper = EX[f"Paper_{row['paper_id']}"]
        
        # Add triples to the graph
        g.add((review, EX.reviewed_on, paper))

# Serialize the graph in Turtle format
g.serialize(destination='turtle/review_on.ttl', format='turtle')
# Out:
# <Graph identifier=Na98b186942cf41d38ffcc2d97a3a7286 (<class 'rdflib.graph.Graph'>)>

# %%
import rdflib
from urllib.parse import quote

# Function to correct IRIs in the graph
def correct_iri(graph):
    corrected_graph = rdflib.Graph()
    for s, p, o in graph:
        new_s = rdflib.URIRef(quote(str(s), safe=":/#"))
        new_o = o
        if isinstance(o, rdflib.URIRef):
            new_o = rdflib.URIRef(quote(str(o), safe=":/#"))
        corrected_graph.add((new_s, p, new_o))
    return corrected_graph

# Load your TTL file
g = rdflib.Graph()
try:
    g.parse("turtle/affiliations.ttl", format="ttl")
    corrected_g = correct_iri(g)
    # Save the corrected graph
    corrected_g.serialize("corrected_affiliated_with.ttl", format="ttl")
    print("Corrected TTL has been saved.")
except Exception as e:
    print(f"Error loading or correcting TTL: {e}")
# Out:
# Corrected TTL has been saved.

# %% [markdown]
# Now lets connect to out GraphDb, with some queries we can check if the abox is uploaded and connected sucesfully

# %%
pip install SPARQLWrapper
# Out:
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting rdflib>=6.1.1 (from SPARQLWrapper)
#   Downloading rdflib-7.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=6.1.1->SPARQLWrapper)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting pyparsing<4,>=2.1.0 (from rdflib>=6.1.1->SPARQLWrapper)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: six in c:\users\kocak\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.16.0)
# Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#    ---------------------------------------- 0.0/531.9 kB ? eta -:--:--
#    ---------- ----------------------------- 133.1/531.9 kB 4.0 MB/s eta 0:00:01
#    --------------------------------- ------ 440.3/531.9 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 531.9/531.9 kB 4.8 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#    ---------------------------------------- 41.7/41.7 kB 2.0 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: pyparsing, isodate, rdflib, SPARQLWrapper
# Successfully installed SPARQLWrapper-2.0.0 isodate-0.6.1 pyparsing-3.1.2 rdflib-7.0.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Lets check if written_by_enriched and authours are connected. If we can reach, papers with the authour names we can verify it.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# Configure the SPARQL endpoint
sparql = SPARQLWrapper("http://DESKTOP-GN9MFGC:7200/repositories/academic-papers-p2")
#sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/lab2")


# Define the query
query = """
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>

SELECT ?paper ?authorName
WHERE {
  # ?paper ex:written_by ?author .
  # ?author foaf:name ?authorName .
}
LIMIT 15
"""

# Set the query and the return format
sparql.setQuery(query)
sparql.setReturnFormat(JSON)

# Execute the query and process results
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    print(f'Paper: {result["paper"]["value"]}, Author Name: {result["authorName"]["value"]}')
# Out:
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89, Author Name: Wang-Chien Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-1, Author Name: Wang-Chien Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-2, Author Name: Wang-Chien Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-3, Author Name: Wang-Chien Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-4, Author Name: Wang-Chien Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-5, Author Name: Wang-Chien Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-6, Author Name: Wang-Chien Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-7, Author Name: Wang-Chien Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-8, Author Name: Wang-Chien Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89, Author Name: Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-1, Author Name: Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-2, Author Name: Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-3, Author Name: Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-4, Author Name: Lee
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-5, Author Name: Lee

# %% [markdown]
# Lets check if authours are correctly linked to their respective institutions

# %%
def query_authors_and_affiliations():
    # Set up the SPARQL connection to your GraphDB instance
    #sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/lab2")
    
    # Define your SPARQL query
    query = """
    PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX ap: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

    SELECT ?authorName ?affiliationName
    WHERE {
      # ?author ex:affiliated_with ?affiliation .
      # ?author foaf:name ?authorName .
      # ?affiliation ap:affiliation_name ?affiliationName .
    }
    LIMIT 100
    """
    
    # Set the query to the SPARQL connection and specify the return format as JSON
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    # Execute the query and get the results
    results = sparql.query().convert()
    
    # Print the results
    for result in results["results"]["bindings"]:
        print(f'Author Name: {result["authorName"]["value"]}, Affiliation Name: {result["affiliationName"]["value"]}')

# Run the function to query GraphDB
query_authors_and_affiliations()
# Out:
# Author Name: Claudia Gonzalez Viejo, Affiliation Name: University of Washington
# Author Name: S. Fuentes, Affiliation Name: University of Washington
# Author Name: Gaurang Sonkavde, Affiliation Name: University of Washington
# Author Name: Yaroslav Ganin, Affiliation Name: University of Washington
# Author Name: Y. Kim, Affiliation Name: University of Washington
# Author Name: W. Kew, Affiliation Name: University of Washington
# Author Name: A. Barto, Affiliation Name: University of Washington
# Author Name: B. Landfeldt, Affiliation Name: University of Washington
# Author Name: Julia Chuzhoy, Affiliation Name: University of Washington
# Author Name: A. Gionis, Affiliation Name: University of Washington
# Author Name: P. H. Seo, Affiliation Name: University of Washington
# Author Name: Dany Laksono, Affiliation Name: University of Washington
# Author Name: C. Mulligan, Affiliation Name: University of Washington
# Author Name: Yin Lu, Affiliation Name: University of Washington
# Author Name: Dan Suciu, Affiliation Name: University of Washington
# Author Name: S. Naqvi, Affiliation Name: University of Washington
# Author Name: A. Borgatto, Affiliation Name: University of Washington
# Author Name: Yulyani Arifin, Affiliation Name: University of Washington
# Author Name: David L. Wheeler, Affiliation Name: University of Washington
# Author Name: D. Church, Affiliation Name: University of Washington
# Author Name: V. Vysotska, Affiliation Name: Yale University
# Author Name: Barry Liu, Affiliation Name: Yale University
# Author Name: L. Lewin-Eytan, Affiliation Name: Yale University
# Author Name: Dong-chan Lee, Affiliation Name: Yale University
# Author Name: Yeonguk Yu, Affiliation Name: Yale University
# Author Name: Gautam Das, Affiliation Name: Yale University
# Author Name: J. D. Pons, Affiliation Name: Yale University
# Author Name: A. Elmagarmid, Affiliation Name: Yale University
# Author Name: Jim Brown, Affiliation Name: Yale University
# Author Name: M. Dunham, Affiliation Name: Yale University
# Author Name: María del Mar Roldán García, Affiliation Name: Yale University
# Author Name: Sudeepa Roy, Affiliation Name: Yale University
# Author Name: Madjid Meziane, Affiliation Name: Yale University
# Author Name: Rune Jönsson, Affiliation Name: Yale University
# Author Name: B. Catania, Affiliation Name: Yale University
# Author Name: S. Lessard, Affiliation Name: Yale University
# Author Name: B. Mendis, Affiliation Name: Yale University
# Author Name: P. Karp, Affiliation Name: Yale University
# Author Name: Amgad Agoub, Affiliation Name: Yale University
# Author Name: L. Tardón, Affiliation Name: Yale University
# Author Name: M. Potey, Affiliation Name: Yale University
# Author Name: R. Unnithan, Affiliation Name: University of Pennsylvania
# Author Name: S. Kiranyaz, Affiliation Name: University of Pennsylvania
# Author Name: Xin Liu, Affiliation Name: University of Pennsylvania
# Author Name: Diana Sungatullina, Affiliation Name: University of Pennsylvania
# Author Name: A. Kucera, Affiliation Name: University of Pennsylvania
# Author Name: Petr Novotný, Affiliation Name: University of Pennsylvania
# Author Name: L. May, Affiliation Name: University of Pennsylvania
# Author Name: N. Vieille, Affiliation Name: University of Pennsylvania

# %% [markdown]
# Lets check authours and papers

# %%
def query_papers_with_authors():
    # Set up the SPARQL connection to your GraphDB instance
    #sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/lab2")
    
    # Define your SPARQL query
    query = """
    PREFIX ns1: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>

    SELECT ?paperTitle ?authorName
    WHERE {
      # ?paper ns1:title ?paperTitle.
      # ?paper ns1:written_by ?author.
      # ?author foaf:name ?authorName.
    }
    """
    
    # Set the query to the SPARQL connection and specify the return format as JSON
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    # Execute the query and get the results
    results = sparql.query().convert()
    
    # Print the results
    print("Papers with Their Authors:")
    for result in results["results"]["bindings"]:
        print(f'Paper Title: {result["paperTitle"]["value"]}, Author Name: {result["authorName"]["value"]}')

# Run the function to query GraphDB
query_papers_with_authors()
# Out:
# Papers with Their Authors:
# Paper Title: Signature File Methods for Indexing Object-Oriented Database Systems, Author Name: Wang-Chien Lee
# Paper Title: Signature File Methods for Indexing Object-Oriented Database Systems-1, Author Name: Wang-Chien Lee
# Paper Title: Signature File Methods for Indexing Object-Oriented Database Systems-2, Author Name: Wang-Chien Lee
# Paper Title: Signature File Methods for Indexing Object-Oriented Database Systems-3, Author Name: Wang-Chien Lee
# Paper Title: Signature File Methods for Indexing Object-Oriented Database Systems-4, Author Name: Wang-Chien Lee
# Paper Title: Signature File Methods for Indexing Object-Oriented Database Systems-5, Author Name: Wang-Chien Lee
# Paper Title: Advanced Techniques for Content-Based Management of Multimedia Databases-2, Author Name: S. Kiranyaz
# Paper Title: Advanced Techniques for Content-Based Management of Multimedia Databases-3, Author Name: S. Kiranyaz
# Paper Title: Advanced Techniques for Content-Based Management of Multimedia Databases-4, Author Name: S. Kiranyaz
# Paper Title: Advanced Techniques for Content-Based Management of Multimedia Databases-5, Author Name: S. Kiranyaz
# Paper Title: Advanced Techniques for Content-Based Management of Multimedia Databases-6, Author Name: S. Kiranyaz
# Paper Title: Advanced Techniques for Content-Based Management of Multimedia Databases-7, Author Name: S. Kiranyaz
# Paper Title: Advanced Techniques for Content-Based Management of Multimedia Databases-8, Author Name: S. Kiranyaz
# Paper Title: Computational Trust Models and Machine Learning, Author Name: Anwitaman Datta
# Paper Title: Computational Trust Models and Machine Learning-1, Author Name: Anwitaman Datta
# Paper Title: Computational Trust Models and Machine Learning-2, Author Name: Anwitaman Datta
# Paper Title: Computational Trust Models and Machine Learning-3, Author Name: Anwitaman Datta
# Paper Title: Computational Trust Models and Machine Learning-4, Author Name: Anwitaman Datta
# Paper Title: Computational Trust Models and Machine Learning-5, Author Name: Anwitaman Datta
# Paper Title: Computational Trust Models and Machine Learning-6, Author Name: Anwitaman Datta
# Paper Title: Computational Trust Models and Machine Learning-7, Author Name: Anwitaman Datta
# Paper Title: Computational Trust Models and Machine Learning-8, Author Name: Anwitaman Datta
# Paper Title: Computational Trust Models and Machine Learning, Author Name: Ee-Peng Lim
# Paper Title: Computational Trust Models and Machine Learning-1, Author Name: Ee-Peng Lim
# Paper Title: Computational Trust Models and Machine Learning-2, Author Name: Ee-Peng Lim
# Paper Title: Computational Trust Models and Machine Learning-3, Author Name: Ee-Peng Lim
# Paper Title: Computational Trust Models and Machine Learning-4, Author Name: Ee-Peng Lim
# Paper Title: Computational Trust Models and Machine Learning-5, Author Name: Ee-Peng Lim
# Paper Title: Computational Trust Models and Machine Learning-6, Author Name: Ee-Peng Lim
# Paper Title: Computational Trust Models and Machine Learning-7, Author Name: Ee-Peng Lim
# Paper Title: Computational Trust Models and Machine Learning-8, Author Name: Ee-Peng Lim
# Paper Title: Computational Trust Models and Machine Learning, Author Name: Xin Liu
# Paper Title: Computational Trust Models and Machine Learning-1, Author Name: Xin Liu
# Paper Title: Computational Trust Models and Machine Learning-2, Author Name: Xin Liu
# Paper Title: Computational Trust Models and Machine Learning-3, Author Name: Xin Liu
# Paper Title: Computational Trust Models and Machine Learning-4, Author Name: Xin Liu
# Paper Title: Computational Trust Models and Machine Learning-5, Author Name: Xin Liu
# Paper Title: Computational Trust Models and Machine Learning-6, Author Name: Xin Liu
# Paper Title: Computational Trust Models and Machine Learning-7, Author Name: Xin Liu
# Paper Title: Computational Trust Models and Machine Learning-8, Author Name: Xin Liu
# Paper Title: Combining Machine Learning with Knowledge Engineering to detect Fake News in Social Networks - A Survey, Author Name: Knut Hinkelmann
# Paper Title: Combining Machine Learning with Knowledge Engineering to detect Fake News in Social Networks - A Survey-1, Author Name: Knut Hinkelmann
# Paper Title: Combining Machine Learning with Knowledge Engineering to detect Fake News in Social Networks - A Survey-2, Author Name: Knut Hinkelmann
# Paper Title: Combining Machine Learning with Knowledge Engineering to detect Fake News in Social Networks - A Survey-3, Author Name: Knut Hinkelmann
# Paper Title: Combining Machine Learning with Knowledge Engineering to detect Fake News in Social Networks - A Survey-4, Author Name: Knut Hinkelmann
# Paper Title: Combining Machine Learning with Knowledge Engineering to detect Fake News in Social Networks - A Survey-5, Author Name: Knut Hinkelmann
# Paper Title: Combining Machine Learning with Knowledge Engineering to detect Fake News in Social Networks - A Survey
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students, Author Name: Ferdinand Timmermann
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-1, Author Name: Ferdinand Timmermann
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-2, Author Name: Ferdinand Timmermann
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-3, Author Name: Ferdinand Timmermann
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-4, Author Name: Ferdinand Timmermann
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-5, Author Name: Ferdinand Timmermann
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-6, Author Name: Ferdinand Timmermann
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-7, Author Name: Ferdinand Timmermann
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-8, Author Name: Ferdinand Timmermann
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students, Author Name: F. Berlth
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-1, Author Name: F. Berlth
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-2, Author Name: F. Berlth
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-3, Author Name: F. Berlth
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-4, Author Name: F. Berlth
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-5, Author Name: F. Berlth
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-6, Author Name: F. Berlth
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-7, Author Name: F. Berlth
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-8, Author Name: F. Berlth
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students, Author Name: N. Schuelper
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-1, Author Name: N. Schuelper
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-2, Author Name: N. Schuelper
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-3, Author Name: N. Schuelper
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-4, Author Name: N. Schuelper
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-5, Author Name: N. Schuelper
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-6, Author Name: N. Schuelper
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-7, Author Name: N. Schuelper
# Paper Title: Serious Games in Surgical Medical Education: A Virtual Emergency Department as a Tool for Teaching Clinical Reasoning to Medical Students-8, Author Name: N. Schuelper
# Paper Title: Forecasting Stock Market Prices Using Machine Learning and Deep Learning Models: A Systematic Review, Performance Analysis and Discussion of Implications, Author Name: D. Doreswamy
# Paper Title: Forecasting Stock Market Prices Using Machine Learning and Deep Learning Models: A Systematic Review, Performance Analysis and Discussion of Implications-1, Author Name: D. Doreswamy
# ...
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments, Author Name: Mahmoud Moustafa Eyada
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-1, Author Name: Mahmoud Moustafa Eyada
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-2, Author Name: Mahmoud Moustafa Eyada
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-3, Author Name: Mahmoud Moustafa Eyada
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-4, Author Name: Mahmoud Moustafa Eyada
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-5, Author Name: Mahmoud Moustafa Eyada
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-6, Author Name: Mahmoud Moustafa Eyada
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-7, Author Name: Mahmoud Moustafa Eyada
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-8, Author Name: Mahmoud Moustafa Eyada
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments, Author Name: Walaa Saber
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-1, Author Name: Walaa Saber
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-2, Author Name: Walaa Saber
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-3, Author Name: Walaa Saber
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-4, Author Name: Walaa Saber
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-5, Author Name: Walaa Saber
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-6, Author Name: Walaa Saber
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-7, Author Name: Walaa Saber
# Paper Title: Performance Evaluation of IoT Data Management Using MongoDB Versus MySQL Databases in Different Cloud Environments-8, Author Name: Walaa Saber
# Paper Title: Database Migration from Structured Database to non-Structured Database, Author Name: M. Potey
# Paper Title: Database Migration from Structured Database to non-Structured Database-1, Author Name: M. Potey
# Paper Title: Database Migration from Structured Database to non-Structured Database-2, Author Name: M. Potey
# Paper Title: Database Migration from Structured Database to non-Structured Database-3, Author Name: M. Potey
# Paper Title: Database Migration from Structured Database to non-Structured Database-4, Author Name: M. Potey
# Paper Title: Database Migration from Structured Database to non-Structured Database-5, Author Name: M. Potey
# Paper Title: Database Migration from Structured Database to non-Structured Database-6, Author Name: M. Potey
# Paper Title: Database Migration from Structured Database to non-Structured Database-7, Author Name: M. Potey
# Paper Title: Database Migration from Structured Database to non-Structured Database-8, Author Name: M. Potey
# Paper Title: Database Migration from Structured Database to non-Structured Database, Author Name: M. Nerkar
# Paper Title: Database Migration from Structured Database to non-Structured Database-1, Author Name: M. Nerkar
# Paper Title: Database Migration from Structured Database to non-Structured Database-2, Author Name: M. Nerkar
# Paper Title: Database Migration from Structured Database to non-Structured Database-3, Author Name: M. Nerkar
# Paper Title: Database Migration from Structured Database to non-Structured Database-4, Author Name: M. Nerkar
# Paper Title: Database Migration from Structured Database to non-Structured Database-5, Author Name: M. Nerkar
# Paper Title: Database Migration from Structured Database to non-Structured Database-6, Author Name: M. Nerkar
# Paper Title: Database Migration from Structured Database to non-Structured Database-7, Author Name: M. Nerkar
# Paper Title: Database Migration from Structured Database to non-Structured Database-8, Author Name: M. Nerkar
# Paper Title: Database Migration from Structured Database to non-Structured Database, Author Name: Megha Digrase
# Paper Title: Database Migration from Structured Database to non-Structured Database-1, Author Name: Megha Digrase
# Paper Title: Database Migration from Structured Database to non-Structured Database-2, Author Name: Megha Digrase
# Paper Title: Database Migration from Structured Database to non-Structured Database-3, Author Name: Megha Digrase
# Paper Title: Database Migration from Structured Database to non-Structured Database-4, Author Name: Megha Digrase
# Paper Title: Database Migration from Structured Database to non-Structured Database-5, Author Name: Megha Digrase
# Paper Title: Database Migration from Structured Database to non-Structured Database-6, Author Name: Megha Digrase
# Paper Title: Database Migration from Structured Database to non-Structured Database-7, Author Name: Megha Digrase
# Paper Title: Database Migration from Structured Database to non-Structured Database-8, Author Name: Megha Digrase
# Paper Title: Database Migration from Structured Database to non-Structured Database, Author Name: Gaurav Deshmukh
# Paper Title: Database Migration from Structured Database to non-Structured Database-1, Author Name: Gaurav Deshmukh
# Paper Title: Database Migration from Structured Database to non-Structured Database-2, Author Name: Gaurav Deshmukh
# Paper Title: Database Migration from Structured Database to non-Structured Database-3, Author Name: Gaurav Deshmukh
# Paper Title: Database Migration from Structured Database to non-Structured Database-4, Author Name: Gaurav Deshmukh
# Paper Title: Database Migration from Structured Database to non-Structured Database-5, Author Name: Gaurav Deshmukh
# Paper Title: Database Migration from Structured Database to non-Structured Database-6, Author Name: Gaurav Deshmukh
# Paper Title: Database Migration from Structured Database to non-Structured Database-7, Author Name: Gaurav Deshmukh
# Paper Title: Database Migration from Structured Database to non-Structured Database-8, Author Name: Gaurav Deshmukh
# Paper Title: Databases in Grid Applications: Locality and Distribution, Author Name: P. Watson
# Paper Title: Databases in Grid Applications: Locality and Distribution-1, Author Name: P. Watson
# Paper Title: Databases in Grid Applications: Locality and Distribution-2, Author Name: P. Watson
# Paper Title: Databases in Grid Applications: Locality and Distribution-3, Author Name: P. Watson
# Paper Title: Databases in Grid Applications: Locality and Distribution-4, Author Name: P. Watson
# Paper Title: Databases in Grid Applications: Locality and Distribution-5, Author Name: P. Watson
# Paper Title: Databases in Grid Applications: Locality and Distribution-6, Author Name: P. Watson
# Paper Title: Databases in Grid Applications: Locality and Distribution-7, Author Name: P. Watson
# Paper Title: Databases in Grid Applications: Locality and Distribution-8, Author Name: P. Watson
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract), Author Name: H. T. Kung
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-1, Author Name: H. T. Kung
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-2, Author Name: H. T. Kung
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-3, Author Name: H. T. Kung
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-4, Author Name: H. T. Kung
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-5, Author Name: H. T. Kung
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-6, Author Name: H. T. Kung
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-7, Author Name: H. T. Kung
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-8, Author Name: H. T. Kung
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract), Author Name: P. L. Lehman
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-1, Author Name: P. L. Lehman
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-2, Author Name: P. L. Lehman
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-3, Author Name: P. L. Lehman
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-4, Author Name: P. L. Lehman
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-5, Author Name: P. L. Lehman
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-6, Author Name: P. L. Lehman
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-7, Author Name: P. L. Lehman
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract)-8, Author Name: P. L. Lehman
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU, Author Name: L. Sousa
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-1, Author Name: L. Sousa
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-2, Author Name: L. Sousa
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-3, Author Name: L. Sousa
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-4, Author Name: L. Sousa
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-5, Author Name: L. Sousa
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-6, Author Name: L. Sousa
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-7, Author Name: L. Sousa
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-8, Author Name: L. Sousa
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU, Author Name: P. Trancoso
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-1, Author Name: P. Trancoso
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-2, Author Name: P. Trancoso
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-3, Author Name: P. Trancoso
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-4, Author Name: P. Trancoso
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-5, Author Name: P. Trancoso
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-6, Author Name: P. Trancoso
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-7, Author Name: P. Trancoso
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-8, Author Name: P. Trancoso
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU, Author Name: A. Ilic
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-1, Author Name: A. Ilic
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-2, Author Name: A. Ilic
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-3, Author Name: A. Ilic
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-4, Author Name: A. Ilic
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-5, Author Name: A. Ilic
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-6, Author Name: A. Ilic
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-7, Author Name: A. Ilic
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-8, Author Name: A. Ilic
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU, Author Name: Frederico Pratas
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-1, Author Name: Frederico Pratas
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-2, Author Name: Frederico Pratas
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-3, Author Name: Frederico Pratas
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-4, Author Name: Frederico Pratas
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-5, Author Name: Frederico Pratas
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-6, Author Name: Frederico Pratas
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-7, Author Name: Frederico Pratas
# Paper Title: High-Performance Computing on Heterogeneous Systems: Database Queries on CPU and GPU-8, Author Name: Frederico Pratas
# Paper Title: An XML-Based Database for Knowledge Discovery, Author Name: Rosa Meo
# Paper Title: An XML-Based Database for Knowledge Discovery-1, Author Name: Rosa Meo
# Paper Title: An XML-Based Database for Knowledge Discovery-2, Author Name: Rosa Meo
# Paper Title: An XML-Based Database for Knowledge Discovery-3, Author Name: Rosa Meo
# Paper Title: An XML-Based Database for Knowledge Discovery-4, Author Name: Rosa Meo
# Paper Title: An XML-Based Database for Knowledge Discovery-5, Author Name: Rosa Meo
# Paper Title: An XML-Based Database for Knowledge Discovery-6, Author Name: Rosa Meo
# Paper Title: An XML-Based Database for Knowledge Discovery-7, Author Name: Rosa Meo
# Paper Title: An XML-Based Database for Knowledge Discovery-8, Author Name: Rosa Meo
# Paper Title: An XML-Based Database for Knowledge Discovery, Author Name: G. Psaila
# Paper Title: An XML-Based Database for Knowledge Discovery-1, Author Name: G. Psaila
# Paper Title: An XML-Based Database for Knowledge Discovery-2, Author Name: G. Psaila
# Paper Title: An XML-Based Database for Knowledge Discovery-3, Author Name: G. Psaila
# Paper Title: An XML-Based Database for Knowledge Discovery-4, Author Name: G. Psaila
# Paper Title: An XML-Based Database for Knowledge Discovery-5, Author Name: G. Psaila
# Paper Title: An XML-Based Database for Knowledge Discovery-6, Author Name: G. Psaila
# Paper Title: An XML-Based Database for Knowledge Discovery-7, Author Name: G. Psaila
# Paper Title: An XML-Based Database for Knowledge Discovery-8, Author Name: G. Psaila

# %% [markdown]
# Lets check reviews-reviewed_by-authours

# %%
def query_graphdb():
    # Set up the SPARQL connection to your GraphDB instance
    #sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/lab2")
    
    # Define your SPARQL query
    query = """
    PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
    SELECT ?review ?abstract ?date ?decision ?author
    WHERE {
      # ?review a ex:Review;
              ex:abstract ?abstract;
              ex:date ?date;
              ex:decision ?decision.
      # ?review ex:reviewed_by ?author.
    }
    LIMIT 20
    """
    
    # Set the query to the SPARQL connection and specify the return format as JSON
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    # Execute the query and get the results
    results = sparql.query().convert()
    
    # Print the results
    for result in results["results"]["bindings"]:
        print(f'Review: {result["review"]["value"]}, Abstract: {result["abstract"]["value"]}, '
              f'Date: {result["date"]["value"]}, Decision: {result["decision"]["value"]}, '
              f'Author: {result["author"]["value"]}')

# Run the function to query GraphDB
query_graphdb()
# Out:
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_000d4802-8894-4fb0-9a4e-3d5b305a1fe0, Abstract: Strong sometimes soldier large offer letter. State be us well. Town expert issue opportunity choose., Date: 2020-06-29, Decision: Accepted, Author: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1740145
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review
http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2368474
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_046b7c74-2c87-4e43-b787-881e77d36010, Abstract: Right camera safe use career resource these. Say life month trial matter., Date: 2019-06-20, Decision: Rejected, Author: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_51040845
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_046b7c74-2c87-4e43-b787-881e77d36010, Abstract: Right camera safe use career resource these. Say life month trial matter., Date: 2019-06-20, Decision: Rejected, Author: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2119657963
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_046b7c74-2c87-4e43-b787-881e77d36010, Abstract: Right camera safe use career resource these. Say life month trial matter., Date: 2019-06-20, Decision: Rejected, Author: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2316077

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def query_reviews_on_papers_with_authors():
    # Set up the SPARQL connection to your GraphDB instance
    #sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/lab2")
    
    # Define your SPARQL query
    query = """
    PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>

    SELECT ?review ?abstract ?decision ?paper ?authorName
    WHERE {
      # ?review a ex:Review;
              ex:abstract ?abstract;
              ex:decision ?decision;
              ex:reviewed_on ?paper.
      # ?paper ex:written_by ?author.
      # ?author foaf:name ?authorName.
    }
    LIMIT 20
    """
    
    # Set the query to the SPARQL connection and specify the return format as JSON
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    # Execute the query and get the results
    results = sparql.query().convert()
    
    # Print the results
    for result in results["results"]["bindings"]:
        print(f'Review: {result["review"]["value"]}, Abstract: {result["abstract"]["value"]}, '
              f'Decision: {result["decision"]["value"]}, Paper: {result["paper"]["value"]}, '
              f'Author Name: {result["authorName"]["value"]}')

# Run the function to query GraphDB
query_reviews_on_papers_with_authors()
# Out:
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_000d4802-8894-4fb0-9a4e-3d5b305a1fe0, Abstract: Strong sometimes soldier large offer letter. State be us well. Town expert issue opportunity choose., Decision: Accepted, Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0091346f761e451761f48eadd304bd3fb8a4126e, Author Name: E. Gordon
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_000d4802-8894-4fb0-9a4e-3d5b305a1fe0, Abstract: Strong sometimes soldier large offer letter. State be us well. Town expert issue opportunity choose., Decision: Accepted, Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0091346f761e451761f48eadd304bd3fb8a4126e, Author Name: L. Konopka
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_00be8000-ff8c-41d7-b8ad-eb645761a796, Abstract: Police a themselves make guy. Western paper chance management training move teacher. From choose beat hospital. Reveal challenge husband modern beautiful common. Quickly response question identify month career., Decision: Accepted, Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0014e3f6909edbbf8e4d417baf2b991ffbc2909e, Author Name: M. Ivanović
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_00be8000-ff8c-41d7-b8ad-eb645761a796, Abstract: Police a themselves make guy. Western paper chance management training move teacher. From choose beat hospital. Reveal challenge husband modern beautiful common. Quickly response question identify month career., Decision: Accepted, Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0014e3f6909edbbf8e4d417baf2b991ffbc2909e, Author Name: Z. Bosnić
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_00be8000-ff8c-41d7-b8ad-eb645761a796, Abstract: Police a themselves make guy. Western paper chance management training move teacher. From choose beat hospital. Reveal challenge husband modern beautiful common. Quickly response question identify month career., Decision: Accepted, Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0014e3f6909edbbf8e4d417baf2b991ffbc2909e, Author Name: V. Kurbalija
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_00be8000-ff8c-41d7-b8ad-eb645761a796, Abstract: Police a themselves make guy. Western paper chance management training move teacher. From choose beat hospital. Reveal challenge husband modern beautiful common. Quickly response question identify month career., Decision: Accepted, Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_0513d2e6-0bda-483b-af0e-671c7c683143, Abstract: Tend attention traditional hard. Consumer past event line operation meet., Decision: Rejected, Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00b0779034bc13da8f4eb18ed3d0c3466d759b91, Author Name: M. Hardhienata

# %% [markdown]
# Lets check if papers_details_enriched is sucesfully imported to our database.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def query_paper_details():
    # Set up the SPARQL connection to your GraphDB instance
    #sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/lab2")
    
    # Define your SPARQL query
    query = """
    PREFIX ns1: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

    SELECT DISTINCT ?paper ?abstract ?doi ?keywords ?title ?year
    WHERE {
      # ?paper a ns1:Paper;
             ns1:abstract ?abstract;
             ns1:doi ?doi;
             ns1:keywords ?keywords;
             ns1:title ?title;
             ns1:year ?year.
    }
    ORDER BY ?paper
    """
    
    # Set the query to the SPARQL connection and specify the return format as JSON
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    # Execute the query and get the results
    results = sparql.query().convert()
    
    # Print the results
    print("Paper Details:")
    for result in results["results"]["bindings"]:
        print(f'Paper: {result["paper"]["value"]}, Abstract: {result["abstract"]["value"]}, '
              f'DOI: {result["doi"]["value"]}, Keywords: {result["keywords"]["value"]}, '
              f'Title: {result["title"]["value"]}, Year: {result["year"]["value"]}')

# Run the function to query GraphDB
query_paper_details()
# Out:
# Paper Details:
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89, Abstract: , DOI: , Keywords: , Title: Signature File Methods for Indexing Object-Oriented Database Systems, Year: 1992
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-1, Abstract: , DOI: , Keywords: , Title: Signature File Methods for Indexing Object-Oriented Database Systems-1, Year: 1992
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-2, Abstract: , DOI: , Keywords: , Title: Signature File Methods for Indexing Object-Oriented Database Systems-2, Year: 1992
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-3, Abstract: , DOI: , Keywords: , Title: Signature File Methods for Indexing Object-Oriented Database Systems-3, Year: 1992
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-4, Abstract: , DOI: , Keywords: , Title: Signature File Methods for Indexing Object-Oriented Database Systems-4, Year: 1992
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-5, Abstract: , DOI: , Keywords: , Title: Signature File Methods for Indexing Object-Oriented Database Systems-5, Year: 1992
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-6, Abstract: , DOI: , Keywords: , Title: Signature File Methods for Indexing Object-Oriented Database Systems-6, Year: 1992
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-7, Abstract: , DOI: , Keywords: , Title: Signature File Methods for Indexing Object-Oriented Database Systems-7, Year: 1992
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0000d36f99f61d6768e7c21c46ce4350b41a6a89-8, Abstract: , DOI: , Keywords: , Title: Signature File Methods for Indexing Object-Oriented Database Systems-8, Year: 1992
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00016e315b39d20b69f041790573e2215f9eb028, Abstract: Stakeholders encourage accounting educators to provide active learning opportunities, to integrate the creative use of technology into the curriculum, and to emphasize learning by doing. The principles of good teaching practice can use technology to promote active learning, to provide prompt feedback to students, to increase student time on task, and to make learning more effective and efficient for the student. Technological tools can permit students to become active participants and can improve student learning by giving students convenient access to review material with immediate feedback. This article describes the use and development of a PowerPoint game in an introductory accounting course managerial accounting that provides the student with immediate feedback and is designed to be accessed by the student outside of the classroom. This technological tool can be used in other undergraduate academic disciplines., DOI: 10.4018/jicte.2011040102, Keywords: learning,student,accounting,active,use,feedback,students,provide,technology,technological,immediate,stakeholders,encourage,educators,opportunities,integrate,creative,curriculum,emphasize,principles, Title: Enhance Student Learning with PowerPoint Games: Using Twenty Questions to Promote Active Learning in Managerial Accounting, Year: 2011
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00016e315b39d20b69f041790573e2215f9eb028-8, Abstract: Stakeholders encourage accounting educators to provide active learning opportunities, to integrate the creative use of technology into the curriculum, and to emphasize learning by doing. The principles of good teaching practice can use technology to promote active learning, to provide prompt feedback to students, to increase student time on task, and to make learning more effective and efficient for the student. Technological tools can permit students to become active participants and can improve student learning by giving students convenient access to review material with immediate feedback. This article describes the use and development of a PowerPoint game in an introductory accounting course managerial accounting that provides the student with immediate feedback and is designed to be accessed by the student outside of the classroom. This technological tool can be used in other undergraduate academic disciplines., DOI: 10.4018/jicte.2011040102, Keywords: learning,student,accounting,active,use,feedback,students,provide,technology,technological,immediate,stakeholders,encourage,educators,opportunities,integrate,creative,curriculum,emphasize,principles, Title: Enhance Student Learning with PowerPoint Games: Using Twenty Questions to Promote Active Learning in Managerial Accounting-8, Year: 2011
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba, Abstract: Advances in early insect detection have been reported using digital technologies through camera systems, sensor networks, and remote sensing coupled with machine learning (ML) modeling. However, up to date, there is no cost-effective system to monitor insect presence accurately and insect-plant interactions. This paper presents results on the implementation of near-infrared spectroscopy (NIR) and a low-cost electronic nose (e-nose) coupled with machine learning. Several artificial neural network (ANN) models were developed based on classification to detect the level of infestation and regression to predict insect numbers for both e-nose and NIR inputs, and plant physiological response based on e-nose to predict photosynthesis rate (A), transpiration (E) and stomatal conductance (gs). Results showed high accuracy for classification models ranging within 96.5–99.3% for NIR and between 94.2–99.2% using e-nose data as inputs. For regression models, high correlation coefficients were obtained for physiological parameters (gs, E and A) using e-nose data from all samples as inputs (R = 0.86) and R = 0.94 considering only control plants (no insect presence). Finally, R = 0.97 for NIR and R = 0.99 for e-nose data as inputs were obtained to predict number of insects. Performances for all models developed showed no signs of overfitting. In this paper, a field-based system using unmanned aerial vehicles with the e-nose as payload was proposed and described for deployment of ML models to aid growers in pest management practices., DOI: 10.3390/s21175948, Keywords: models,insect,using,nir,inputs,r,predict,data,coupled,machine,learning,ml,system,presence,paper,results,developed,based,classification,regression, Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling, Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-1, Abstract: Advances in early insect detection have been reported using digital technologies through camera systems, sensor networks, and remote sensing coupled with machine learning (ML) modeling. However, up to date, there is no cost-effective system to monitor insect presence accurately and insect-plant interactions. This paper presents results on the implementation of near-infrared spectroscopy (NIR) and a low-cost electronic nose (e-nose) coupled with machine learning. Several artificial neural network (ANN) models were developed based on classification to detect the level of infestation and regression to predict insect numbers for both e-nose and NIR inputs, and plant physiological response based on e-nose to predict photosynthesis rate (A), transpiration (E) and stomatal conductance (gs). Results showed high accuracy for classification models ranging within 96.5–99.3% for NIR and between 94.2–99.2% using e-nose data as inputs. For regression models, high correlation coefficients were obtained for physiological parameters (gs, E and A) using e-nose data from all samples as inputs (R = 0.86) and R = 0.94 considering only control plants (no insect presence). Finally, R = 0.97 for NIR and R = 0.99 for e-nose data as inputs were obtained to predict number of insects. Performances for all models developed showed no signs of overfitting. In this paper, a field-based system using unmanned aerial vehicles with the e-nose as payload was proposed and described for deployment of ML models to aid growers in pest management practices., DOI: 10.3390/s21175948, Keywords: models,insect,using,nir,inputs,r,predict,data,coupled,machine,learning,ml,system,presence,paper,results,developed,based,classification,regression, Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling-1, Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-2, Abstract: Advances in early insect detection have been reported using digital technologies through camera systems, sensor networks, and remote sensing coupled with machine learning (ML) modeling. However, up to date, there is no cost-effective system to monitor insect presence accurately and insect-plant interactions. This paper presents results on the implementation of near-infrared spectroscopy (NIR) and a low-cost electronic nose (e-nose) coupled with machine learning. Several artificial neural network (ANN) models were developed based on classification to detect the level of infestation and regression to predict insect numbers for both e-nose and NIR inputs, and plant physiological response based on e-nose to predict photosynthesis rate (A), transpiration (E) and stomatal conductance (gs). Results showed high accuracy for classification models ranging within 96.5–99.3% for NIR and between 94.2–99.2% using e-nose data as inputs. For regression models, high correlation coefficients were obtained for physiological parameters (gs, E and A) using e-nose data from all samples as inputs (R = 0.86) and R = 0.94 considering only control plants (no insect presence). Finally, R = 0.97 for NIR and R = 0.99 for e-nose data as inputs were obtained to predict number of insects. Performances for all models developed showed no signs of overfitting. In this paper, a field-based system using unmanned aerial vehicles with the e-nose as payload was proposed and described for deployment of ML models to aid growers in pest management practices., DOI: 10.3390/s21175948, Keywords: models,insect,using,nir,inputs,r,predict,data,coupled,machine,learning,ml,system,presence,paper,results,developed,based,classification,regression, Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling-2, Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-3, Abstract: Advances in early insect detection have been reported using digital technologies through camera systems, sensor networks, and remote sensing coupled with machine learning (ML) modeling. However, up to date, there is no cost-effective system to monitor insect presence accurately and insect-plant interactions. This paper presents results on the implementation of near-infrared spectroscopy (NIR) and a low-cost electronic nose (e-nose) coupled with machine learning. Several artificial neural network (ANN) models were developed based on classification to detect the level of infestation and regression to predict insect numbers for both e-nose and NIR inputs, and plant physiological response based on e-nose to predict photosynthesis rate (A), transpiration (E) and stomatal conductance (gs). Results showed high accuracy for classification models ranging within 96.5–99.3% for NIR and between 94.2–99.2% using e-nose data as inputs. For regression models, high correlation coefficients were obtained for physiological parameters (gs, E and A) using e-nose data from all samples as inputs (R = 0.86) and R = 0.94 considering only control plants (no insect presence). Finally, R = 0.97 for NIR and R = 0.99 for e-nose data as inputs were obtained to predict number of insects. Performances for all models developed showed no signs of overfitting. In this paper, a field-based system using unmanned aerial vehicles with the e-nose as payload was proposed and described for deployment of ML models to aid growers in pest management practices., DOI: 10.3390/s21175948, Keywords: models,insect,using,nir,inputs,r,predict,data,coupled,machine,learning,ml,system,presence,paper,results,developed,based,classification,regression, Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling-3, Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-4, Abstract: Advances in early insect detection have been reported using digital technologies through camera systems, sensor networks, and remote sensing coupled with machine learning (ML) modeling. However, up to date, there is no cost-effective system to monitor insect presence accurately and insect-plant interactions. This paper presents results on the implementation of near-infrared spectroscopy (NIR) and a low-cost electronic nose (e-nose) coupled with machine learning. Several artificial neural network (ANN) models were developed based on classification to detect the level of infestation and regression to predict insect numbers for both e-nose and NIR inputs, and plant physiological response based on e-nose to predict photosynthesis rate (A), transpiration (E) and stomatal conductance (gs). Results showed high accuracy for classification models ranging within 96.5–99.3% for NIR and between 94.2–99.2% using e-nose data as inputs. For regression models, high correlation coefficients were obtained for physiological parameters (gs, E and A) using e-nose data from all samples as inputs (R = 0.86) and R = 0.94 considering only control plants (no insect presence). Finally, R = 0.97 for NIR and R = 0.99 for e-nose data as inputs were obtained to predict number of insects. Performances for all models developed showed no signs of overfitting. In this paper, a field-based system using unmanned aerial vehicles with the e-nose as payload was proposed and described for deployment of ML models to aid growers in pest management practices., DOI: 10.3390/s21175948, Keywords: models,insect,using,nir,inputs,r,predict,data,coupled,machine,learning,ml,system,presence,paper,results,developed,based,classification,regression, Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling-4, Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-5, Abstract: Advances in early insect detection have been reported using digital technologies through camera systems, sensor networks, and remote sensing coupled with machine learning (ML) modeling. However, up to date, there is no cost-effective system to monitor insect presence accurately and insect-plant interactions. This paper presents results on the implementation of near-infrared spectroscopy (NIR) and a low-cost electronic nose (e-nose) coupled with machine learning. Several artificial neural network (ANN) models were developed based on classification to detect the level of infestation and regression to predict insect numbers for both e-nose and NIR inputs, and plant physiological response based on e-nose to predict photosynthesis rate (A), transpiration (E) and stomatal conductance (gs). Results showed high accuracy for classification models ranging within 96.5–99.3% for NIR and between 94.2–99.2% using e-nose data as inputs. For regression models, high correlation coefficients were obtained for physiological parameters (gs, E and A) using e-nose data from all samples as inputs (R = 0.86) and R = 0.94 considering only control plants (no insect presence). Finally, R = 0.97 for NIR and R = 0.99 for e-nose data as inputs were obtained to predict number of insects. Performances for all models developed showed no signs of overfitting. In this paper, a field-based system using unmanned aerial vehicles with the e-nose as payload was proposed and described for deployment of ML models to aid growers in pest management practices., DOI: 10.3390/s21175948, Keywords: models,insect,using,nir,inputs,r,predict,data,coupled,machine,learning,ml,system,presence,paper,results,developed,based,classification,regression, Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling-5, Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-6, Abstract: Advances in early insect detection have been reported using digital technologies through camera systems, sensor networks, and remote sensing coupled with machine learning (ML) modeling. However, up to date, there is no cost-effective system to monitor insect presence accurately and insect-plant interactions. This paper presents results on the implementation of near-infrared spectroscopy (NIR) and a low-cost electronic nose (e-nose) coupled with machine learning. Several artificial neural network (ANN) models were developed based on classification to detect the level of infestation and regression to predict insect numbers for both e-nose and NIR inputs, and plant physiological response based on e-nose to predict photosynthesis rate (A), transpiration (E) and stomatal conductance (gs). Results showed high accuracy for classification models ranging within 96.5–99.3% for NIR and between 94.2–99.2% using e-nose data as inputs. For regression models, high correlation coefficients were obtained for physiological parameters (gs, E and A) using e-nose data from all samples as inputs (R = 0.86) and R = 0.94 considering only control plants (no insect presence). Finally, R = 0.97 for NIR and R = 0.99 for e-nose data as inputs were obtained to predict number of insects. Performances for all models developed showed no signs of overfitting. In this paper, a field-based system using unmanned aerial vehicles with the e-nose as payload was proposed and described for deployment of ML models to aid growers in pest management practices., DOI: 10.3390/s21175948, Keywords: models,insect,using,nir,inputs,r,predict,data,coupled,machine,learning,ml,system,presence,paper,results,developed,based,classification,regression, Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling-6, Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-7, Abstract: Advances in early insect detection have been reported using digital technologies through camera systems, sensor networks, and remote sensing coupled with machine learning (ML) modeling. However, up to date, there is no cost-effective system to monitor insect presence accurately and insect-plant interactions. This paper presents results on the implementation of near-infrared spectroscopy (NIR) and a low-cost electronic nose (e-nose) coupled with machine learning. Several artificial neural network (ANN) models were developed based on classification to detect the level of infestation and regression to predict insect numbers for both e-nose and NIR inputs, and plant physiological response based on e-nose to predict photosynthesis rate (A), transpiration (E) and stomatal conductance (gs). Results showed high accuracy for classification models ranging within 96.5–99.3% for NIR and between 94.2–99.2% using e-nose data as inputs. For regression models, high correlation coefficients were obtained for physiological parameters (gs, E and A) using e-nose data from all samples as inputs (R = 0.86) and R = 0.94 considering only control plants (no insect presence). Finally, R = 0.97 for NIR and R = 0.99 for e-nose data as inputs were obtained to predict number of insects. Performances for all models developed showed no signs of overfitting. In this paper, a field-based system using unmanned aerial vehicles with the e-nose as payload was proposed and described for deployment of ML models to aid growers in pest management practices., DOI: 10.3390/s21175948, Keywords: models,insect,using,nir,inputs,r,predict,data,coupled,machine,learning,ml,system,presence,paper,results,developed,based,classification,regression, Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling-7, Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-8, Abstract: Advances in early insect detection have been reported using digital technologies through camera systems, sensor networks, and remote sensing coupled with machine learning (ML) modeling. However, up to date, there is no cost-effective system to monitor insect presence accurately and insect-plant interactions. This paper presents results on the implementation of near-infrared spectroscopy (NIR) and a low-cost electronic nose (e-nose) coupled with machine learning. Several artificial neural network (ANN) models were developed based on classification to detect the level of infestation and regression to predict insect numbers for both e-nose and NIR inputs, and plant physiological response based on e-nose to predict photosynthesis rate (A), transpiration (E) and stomatal conductance (gs). Results showed high accuracy for classification models ranging within 96.5–99.3% for NIR and between 94.2–99.2% using e-nose data as inputs. For regression models, high correlation coefficients were obtained for physiological parameters (gs, E and A) using e-nose data from all samples as inputs (R = 0.86) and R = 0.94 considering only control plants (no insect presence). Finally, R = 0.97 for NIR and R = 0.99 for e-nose data as inputs were obtained to predict number of insects. Performances for all models developed showed no signs of overfitting. In this paper, a field-based system using unmanned aerial vehicles with the e-nose as payload was proposed and described for deployment of ML models to aid growers in pest management practices., DOI: 10.3390/s21175948, Keywords: models,insect,using,nir,inputs,r,predict,data,coupled,machine,learning,ml,system,presence,paper,results,developed,based,classification,regression, Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling-8, Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0004bfb2afc73e755c6c4987225907472da966d1, Abstract: In this paper, we consider reachability games over general hybrid systems, and distinguish between two possible observation frameworks for those games: either the precise dynamics of the system is seen by the players (this is the perfect observation framework), or only the starting point and the delays are known by the players (this is the partial observation framework). In the first more classical framework, we show that time-abstract bisimulation is not adequate for solving this problem, although it is sufficient in the case of timed automata . That is why we consider an other equivalence, namely the suffix equivalence based on the encoding of trajectories through words. We show that this suffix equivalence is in general a correct abstraction for games. We apply this result to o-minimal hybrid systems, and get decidability and computability results in this framework. For the second framework which assumes a partial observation of the dynamics of the system, we propose another abstraction, called the superword encoding, which is suitable to solve the games under that assumption. In that framework, we also provide decidability and computability results., DOI: 10.2168/LMCS-6(1:1)2010, Keywords: framework,games,observation,equivalence,consider,general,hybrid,systems,dynamics,system,players,partial,show,suffix,encoding,abstraction,decidability,computability,results,paper, Title: O-Minimal Hybrid Reachability Games, Year: 2009
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0004bfb2afc73e755c6c4987225907472da966d1-1, Abstract: In this paper, we consider reachability games over general hybrid systems, and distinguish between two possible observation frameworks for those games: either the precise dynamics of the system is seen by the players (this is the perfect observation framework), or only the starting point and the delays are known by the players (this is the partial observation framework). In the first more classical framework, we show that time-abstract bisimulation is not adequate for solving this problem, although it is sufficient in the case of timed automata . That is why we consider an other equivalence, namely the suffix equivalence based on the encoding of trajectories through words. We show that this suffix equivalence is in general a correct abstraction for games. We apply this result to o-minimal hybrid systems, and get decidability and computability results in this framework. For the second framework which assumes a partial observation of the dynamics of the system, we propose another abstraction, called the superword encoding, which is suitable to solve the games under that assumption. In that framework, we also provide decidability and computability results., DOI: 10.2168/LMCS-6(1:1)2010, Keywords: framework,games,observation,equivalence,consider,general,hybrid,systems,dynamics,system,players,partial,show,suffix,encoding,abstraction,decidability,computability,results,paper, Title: O-Minimal Hybrid Reachability Games-1, Year: 2009
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0004bfb2afc73e755c6c4987225907472da966d1-2, Abstract: In this paper, we consider reachability games over general hybrid systems, and distinguish between two possible observation frameworks for those games: either the precise dynamics of the system is seen by the players (this is the perfect observation framework), or only the starting point and the delays are known by the players (this is the partial observation framework). In the first more classical framework, we show that time-abstract bisimulation is not adequate for solving this problem, although it is sufficient in the case of timed automata . That is why we consider an other equivalence, namely the suffix equivalence based on the encoding of trajectories through words. We show that this suffix equivalence is in general a correct abstraction for games. We apply this result to o-minimal hybrid systems, and get decidability and computability results in this framework. For the second framework which assumes a partial observation of the dynamics of the system, we propose another abstraction, called the superword encoding, which is suitable to solve the games under that assumption. In that framework, we also provide decidability and computability results., DOI: 10.2168/LMCS-6(1:1)2010, Keywords: framework,games,observation,equivalence,consider,general,hybrid,systems,dynamics,system,players,partial,show,suffix,encoding,abstraction,decidability,computability,results,paper, Title: O-Minimal Hybrid Reachability Games-2, Year: 2009
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0004bfb2afc73e755c6c4987225907472da966d1-3, Abstract: In this paper, we consider reachability games over general hybrid systems, and distinguish between two possible observation frameworks for those games: either the precise dynamics of the system is seen by the players (this is the perfect observation framework), or only the starting point and the delays are known by the players (this is the partial observation framework). In the first more classical framework, we show that time-abstract bisimulation is not adequate for solving this problem, although it is sufficient in the case of timed automata . That is why we consider an other equivalence, namely the suffix equivalence based on the encoding of trajectories through words. We show that this suffix equivalence is in general a correct abstraction for games. We apply this result to o-minimal hybrid systems, and get decidability and computability results in this framework. For the second framework which assumes a partial observation of the dynamics of the system, we propose another abstraction, called the superword encoding, which is suitable to solve the games under that assumption. In that framework, we also provide decidability and computability results., DOI: 10.2168/LMCS-6(1:1)2010, Keywords: framework,games,observation,equivalence,consider,general,hybrid,systems,dynamics,system,players,partial,show,suffix,encoding,abstraction,decidability,computability,results,paper, Title: O-Minimal Hybrid Reachability Games-3, Year: 2009
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0004bfb2afc73e755c6c4987225907472da966d1-4, Abstract: In this paper, we consider reachability games over general hybrid systems, and distinguish between two possible observation frameworks for those games: either the precise dynamics of the system is seen by the players (this is the perfect observation framework), or only the starting point and the delays are known by the players (this is the partial observation framework). In the first more classical framework, we show that time-abstract bisimulation is not adequate for solving this problem, although it is sufficient in the case of timed automata . That is why we consider an other equivalence, namely the suffix equivalence based on the encoding of trajectories through words. We show that this suffix equivalence is in general a correct abstraction for games. We apply this result to o-minimal hybrid systems, and get decidability and computability results in this framework. For the second framework which assumes a partial observation of the dynamics of the system, we propose another abstraction, called the superword encoding, which is suitable to solve the games under that assumption. In that framework, we also provide decidability and computability results., DOI: 10.2168/LMCS-6(1:1)2010, Keywords: framework,games,observation,equivalence,consider,general,hybrid,systems,dynamics,system,players,partial,show,suffix,encoding,abstraction,decidability,computability,results,paper, Title: O-Minimal Hybrid Reachability Games-4, Year: 2009
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0004bfb2afc73e755c6c4987225907472da966d1-5, Abstract: In this paper, we consider reachability games over general hybrid systems, and distinguish between two possible observation frameworks for those games: either the precise dynamics of the system is seen by the players (this is the perfect observation framework), or only the starting point and the delays are known by the players (this is the partial observation framework). In the first more classical framework, we show that time-abstract bisimulation is not adequate for solving this problem, although it is sufficient in the case of timed automata . That is why we consider an other equivalence, namely the suffix equivalence based on the encoding of trajectories through words. We show that this suffix equivalence is in general a correct abstraction for games. We apply this result to o-minimal hybrid systems, and get decidability and computability results in this framework. For the second framework which assumes a partial observation of the dynamics of the system, we propose another abstraction, called the superword encoding, which is suitable to solve the games under that assumption. In that framework, we also provide decidability and computability results., DOI: 10.2168/LMCS-6(1:1)2010, Keywords: framework,games,observation,equivalence,consider,general,hybrid,systems,dynamics,system,players,partial,show,suffix,encoding,abstraction,decidability,computability,results,paper, Title: O-Minimal Hybrid Reachability Games-5, Year: 2009
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0004bfb2afc73e755c6c4987225907472da966d1-6, Abstract: In this paper, we consider reachability games over general hybrid systems, and distinguish between two possible observation frameworks for those games: either the precise dynamics of the system is seen by the players (this is the perfect observation framework), or only the starting point and the delays are known by the players (this is the partial observation framework). In the first more classical framework, we show that time-abstract bisimulation is not adequate for solving this problem, although it is sufficient in the case of timed automata . That is why we consider an other equivalence, namely the suffix equivalence based on the encoding of trajectories through words. We show that this suffix equivalence is in general a correct abstraction for games. We apply this result to o-minimal hybrid systems, and get decidability and computability results in this framework. For the second framework which assumes a partial observation of the dynamics of the system, we propose another abstraction, called the superword encoding, which is suitable to solve the games under that assumption. In that framework, we also provide decidability and computability results., DOI: 10.2168/LMCS-6(1:1)2010, Keywords: framework,games,observation,equivalence,consider,general,hybrid,systems,dynamics,system,players,partial,show,suffix,encoding,abstraction,decidability,computability,results,paper, Title: O-Minimal Hybrid Reachability Games-6, Year: 2009
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0004bfb2afc73e755c6c4987225907472da966d1-7, Abstract: In this paper, we consider reachability games over general hybrid systems, and distinguish between two possible observation frameworks for those games: either the precise dynamics of the system is seen by the players (this is the perfect observation framework), or only the starting point and the delays are known by the players (this is the partial observation framework). In the first more classical framework, we show that time-abstract bisimulation is not adequate for solving this problem, although it is sufficient in the case of timed automata . That is why we consider an other equivalence, namely the suffix equivalence based on the encoding of trajectories through words. We show that this suffix equivalence is in general a correct abstraction for games. We apply this result to o-minimal hybrid systems, and get decidability and computability results in this framework. For the second framework which assumes a partial observation of the dynamics of the system, we propose another abstraction, called the superword encoding, which is suitable to solve the games under that assumption. In that framework, we also provide decidability and computability results., DOI: 10.2168/LMCS-6(1:1)2010, Keywords: framework,games,observation,equivalence,consider,general,hybrid,systems,dynamics,system,players,partial,show,suffix,encoding,abstraction,decidability,computability,results,paper, Title: O-Minimal Hybrid Reachability Games-7, Year: 2009
# ...
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0149c0f5b7985d17afc516d932dd17c4205fd4ba-5, Abstract: Database are growing very fast and becoming more complex in the volume (terabyte to petabyte), variety (structured, unstructured and hybrid), and velocity (high speed in growth). Management of database (BigData, so nomenclature) has become the global challenge. The data collection is currently managed and exploited mostly by using conventional data management tools such as classic relational database management systems (RDBMS) or conventional search engines. These systems and tools have been observed to be inefficient and incapable to handle the data in most of the cases e.g.: social networking sites. Efforts are being made to come up with some utility support in order to overcome the observed limitations. The research study was conducted to develop a Cloud-based Utility. It was aimed to convert structural database, SQL to un-structural database, NoSQL [11] systematically and sufficiently. The outcome of the study revealed that the database management becomes considerably scalable, flexible and efficient when traditional RDBMS are complimented by specifically designed rich set of alternative DBMS such as NoSQL, NewSQL based systems. The database conversion shall help in Database analysis and migration from traditional database to today’s BigData., DOI: , Keywords: database,management,data,systems,bigdata,conventional,tools,rdbms,observed,utility,study,nosql,traditional,growing,fast,becoming,complex,volume,terabyte,petabyte, Title: Database Migration from Structured Database to non-Structured Database-5, Year: 2015
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0149c0f5b7985d17afc516d932dd17c4205fd4ba-6, Abstract: Database are growing very fast and becoming more complex in the volume (terabyte to petabyte), variety (structured, unstructured and hybrid), and velocity (high speed in growth). Management of database (BigData, so nomenclature) has become the global challenge. The data collection is currently managed and exploited mostly by using conventional data management tools such as classic relational database management systems (RDBMS) or conventional search engines. These systems and tools have been observed to be inefficient and incapable to handle the data in most of the cases e.g.: social networking sites. Efforts are being made to come up with some utility support in order to overcome the observed limitations. The research study was conducted to develop a Cloud-based Utility. It was aimed to convert structural database, SQL to un-structural database, NoSQL [11] systematically and sufficiently. The outcome of the study revealed that the database management becomes considerably scalable, flexible and efficient when traditional RDBMS are complimented by specifically designed rich set of alternative DBMS such as NoSQL, NewSQL based systems. The database conversion shall help in Database analysis and migration from traditional database to today’s BigData., DOI: , Keywords: database,management,data,systems,bigdata,conventional,tools,rdbms,observed,utility,study,nosql,traditional,growing,fast,becoming,complex,volume,terabyte,petabyte, Title: Database Migration from Structured Database to non-Structured Database-6, Year: 2015
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0149c0f5b7985d17afc516d932dd17c4205fd4ba-7, Abstract: Database are growing very fast and becoming more complex in the volume (terabyte to petabyte), variety (structured, unstructured and hybrid), and velocity (high speed in growth). Management of database (BigData, so nomenclature) has become the global challenge. The data collection is currently managed and exploited mostly by using conventional data management tools such as classic relational database management systems (RDBMS) or conventional search engines. These systems and tools have been observed to be inefficient and incapable to handle the data in most of the cases e.g.: social networking sites. Efforts are being made to come up with some utility support in order to overcome the observed limitations. The research study was conducted to develop a Cloud-based Utility. It was aimed to convert structural database, SQL to un-structural database, NoSQL [11] systematically and sufficiently. The outcome of the study revealed that the database management becomes considerably scalable, flexible and efficient when traditional RDBMS are complimented by specifically designed rich set of alternative DBMS such as NoSQL, NewSQL based systems. The database conversion shall help in Database analysis and migration from traditional database to today’s BigData., DOI: , Keywords: database,management,data,systems,bigdata,conventional,tools,rdbms,observed,utility,study,nosql,traditional,growing,fast,becoming,complex,volume,terabyte,petabyte, Title: Database Migration from Structured Database to non-Structured Database-7, Year: 2015
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0149c0f5b7985d17afc516d932dd17c4205fd4ba-8, Abstract: Database are growing very fast and becoming more complex in the volume (terabyte to petabyte), variety (structured, unstructured and hybrid), and velocity (high speed in growth). Management of database (BigData, so nomenclature) has become the global challenge. The data collection is currently managed and exploited mostly by using conventional data management tools such as classic relational database management systems (RDBMS) or conventional search engines. These systems and tools have been observed to be inefficient and incapable to handle the data in most of the cases e.g.: social networking sites. Efforts are being made to come up with some utility support in order to overcome the observed limitations. The research study was conducted to develop a Cloud-based Utility. It was aimed to convert structural database, SQL to un-structural database, NoSQL [11] systematically and sufficiently. The outcome of the study revealed that the database management becomes considerably scalable, flexible and efficient when traditional RDBMS are complimented by specifically designed rich set of alternative DBMS such as NoSQL, NewSQL based systems. The database conversion shall help in Database analysis and migration from traditional database to today’s BigData., DOI: , Keywords: database,management,data,systems,bigdata,conventional,tools,rdbms,observed,utility,study,nosql,traditional,growing,fast,becoming,complex,volume,terabyte,petabyte, Title: Database Migration from Structured Database to non-Structured Database-8, Year: 2015
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_014cf690afedcb7d8fddaa9d6770f162385ffc99, Abstract: , DOI: 10.1007/11511854_1, Keywords: , Title: Databases in Grid Applications: Locality and Distribution, Year: 2005
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_014cf690afedcb7d8fddaa9d6770f162385ffc99-1, Abstract: , DOI: 10.1007/11511854_1, Keywords: , Title: Databases in Grid Applications: Locality and Distribution-1, Year: 2005
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_014cf690afedcb7d8fddaa9d6770f162385ffc99-2, Abstract: , DOI: 10.1007/11511854_1, Keywords: , Title: Databases in Grid Applications: Locality and Distribution-2, Year: 2005
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_014cf690afedcb7d8fddaa9d6770f162385ffc99-3, Abstract: , DOI: 10.1007/11511854_1, Keywords: , Title: Databases in Grid Applications: Locality and Distribution-3, Year: 2005
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_014cf690afedcb7d8fddaa9d6770f162385ffc99-4, Abstract: , DOI: 10.1007/11511854_1, Keywords: , Title: Databases in Grid Applications: Locality and Distribution-4, Year: 2005
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_014cf690afedcb7d8fddaa9d6770f162385ffc99-5, Abstract: , DOI: 10.1007/11511854_1, Keywords: , Title: Databases in Grid Applications: Locality and Distribution-5, Year: 2005
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0152f2ba5f4765a313e4e41f735a37fca52a2a59, Abstract: , DOI: 10.1007/11896548_61, Keywords: , Title: An XML-Based Database for Knowledge Discovery, Year: 2006
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0152f2ba5f4765a313e4e41f735a37fca52a2a59-1, Abstract: , DOI: 10.1007/11896548_61, Keywords: , Title: An XML-Based Database for Knowledge Discovery-1, Year: 2006
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0152f2ba5f4765a313e4e41f735a37fca52a2a59-2, Abstract: , DOI: 10.1007/11896548_61, Keywords: , Title: An XML-Based Database for Knowledge Discovery-2, Year: 2006
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0152f2ba5f4765a313e4e41f735a37fca52a2a59-3, Abstract: , DOI: 10.1007/11896548_61, Keywords: , Title: An XML-Based Database for Knowledge Discovery-3, Year: 2006
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0152f2ba5f4765a313e4e41f735a37fca52a2a59-4, Abstract: , DOI: 10.1007/11896548_61, Keywords: , Title: An XML-Based Database for Knowledge Discovery-4, Year: 2006
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0152f2ba5f4765a313e4e41f735a37fca52a2a59-5, Abstract: , DOI: 10.1007/11896548_61, Keywords: , Title: An XML-Based Database for Knowledge Discovery-5, Year: 2006
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0152f2ba5f4765a313e4e41f735a37fca52a2a59-6, Abstract: , DOI: 10.1007/11896548_61, Keywords: , Title: An XML-Based Database for Knowledge Discovery-6, Year: 2006
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0152f2ba5f4765a313e4e41f735a37fca52a2a59-7, Abstract: , DOI: 10.1007/11896548_61, Keywords: , Title: An XML-Based Database for Knowledge Discovery-7, Year: 2006
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0152f2ba5f4765a313e4e41f735a37fca52a2a59-8, Abstract: , DOI: 10.1007/11896548_61, Keywords: , Title: An XML-Based Database for Knowledge Discovery-8, Year: 2006

# %% [markdown]
# Lets check if citations are sucesfully imported.

# %%
def query_citations():
    # Set up the SPARQL connection to your GraphDB instance
    #sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/lab2")
    
    # Define your SPARQL query
    query = """
    PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

    SELECT ?paper ?citesTo ?citationYear
    WHERE {
      # ?paper ex:cites_to ?citesTo.
      OPTIONAL { ?paper ex:citation_year ?citationYear. }
    }
    LIMIT 20
    """
    
    # Set the query to the SPARQL connection and specify the return format as JSON
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    # Execute the query and get the results
    results = sparql.query().convert()
    
    # Print the results
    print("Citation Details:")
    for result in results["results"]["bindings"]:
        paper = result["paper"]["value"]
        citesTo = result["citesTo"]["value"]
        citationYear = result.get("citationYear", {}).get("value", "Not provided")
        print(f'Paper: {paper}, Cites To: {citesTo}, Citation Year: {citationYear}')

# Run the function to query GraphDB
query_citations()
# Out:
# Citation Details:
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0082dd304daa17951de672ecfbc17175da4c320e, Citation Year: 2023
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0082dd304daa17951de672ecfbc17175da4c320e, Citation Year: 2019
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0152f2ba5f4765a313e4e41f735a37fca52a2a59, Citation Year: 2023
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00040bdd447f041a50ae95fd51926cf435ef1eba-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0152f2ba5f4765a313e4e41f735a37fca52a2a59, Citation Year: 2019
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0007cd4870abff3c79537a4722d2f6365eb5468f-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00ada6a5c6607c63b7e060d040ddee120d5107ee, Citation Year: 2024
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0009c4975fcb502a4af0e53d46ec6255c13216a1-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_001fed0e97d344c3aa563c704356099a05111949, Citation Year: 2023
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0009c4975fcb502a4af0e53d46ec6255c13216a1-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_001fed0e97d344c3aa563c704356099a05111949, Citation Year: 2022
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0009c4975fcb502a4af0e53d46ec6255c13216a1-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00bc156bac2b39fab1689fe047b23c9f216d7f29, Citation Year: 2023
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0009c4975fcb502a4af0e53d46ec6255c13216a1-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00bc156bac2b39fab1689fe047b23c9f216d7f29, Citation Year: 2022
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_000bc721cefe3f2ba2425e8b95b042dc1e9778f9-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0085bc8aa185ebb0fb18f55cc197c8d98232445d, Citation Year: 2019
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_000cd7ac3435007cca292fc8f1bac86b7a066467-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_002523ab48c0a79567a275c5ba219e95e37d9cca, Citation Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_000cd7ac3435007cca292fc8f1bac86b7a066467-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_002523ab48c0a79567a275c5ba219e95e37d9cca, Citation Year: 2023
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_000cd7ac3435007cca292fc8f1bac86b7a066467-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00b0779034bc13da8f4eb18ed3d0c3466d759b91, Citation Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_000cd7ac3435007cca292fc8f1bac86b7a066467-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00b0779034bc13da8f4eb18ed3d0c3466d759b91, Citation Year: 2023
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_000cd7ac3435007cca292fc8f1bac86b7a066467-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_006707fad29166a3426fbb654d842c6d9292a771, Citation Year: 2021
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_000cd7ac3435007cca292fc8f1bac86b7a066467-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_006707fad29166a3426fbb654d842c6d9292a771, Citation Year: 2023
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0014e3f6909edbbf8e4d417baf2b991ffbc2909e-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_001842ba6c880608a573eeeb2ccd38e9a8ba8281, Citation Year: 2020
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0014e3f6909edbbf8e4d417baf2b991ffbc2909e-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_001842ba6c880608a573eeeb2ccd38e9a8ba8281, Citation Year: 2023
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0014e3f6909edbbf8e4d417baf2b991ffbc2909e-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_001842ba6c880608a573eeeb2ccd38e9a8ba8281, Citation Year: 2022
# Paper: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_0014e3f6909edbbf8e4d417baf2b991ffbc2909e-1, Cites To: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper_00ba98cf43f53a8e9e61b8895a7ca302900e6d7e, Citation Year: 2020

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def query_citation_titles():
    # Set up the SPARQL connection to your GraphDB instance
    #sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/lab2")
    
    # Define your SPARQL query
    query = """
    PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
    PREFIX ns1: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

    SELECT ?citingPaperTitle ?citedPaperTitle
    WHERE {
      # ?citingPaper ex:cites_to ?citedPaper.
      # ?citingPaper ns1:title ?citingPaperTitle.
      # ?citedPaper ns1:title ?citedPaperTitle.
    }
    LIMIT 20
    """
    
    # Set the query to the SPARQL connection and specify the return format as JSON
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    # Execute the query and get the results
    results = sparql.query().convert()
    
    # Print the results
    print("Citation Titles:")
    for result in results["results"]["bindings"]:
        print(f'Citing Paper Title: {result["citingPaperTitle"]["value"]}, Cited Paper Title: {result["citedPaperTitle"]["value"]}')

# Run the function to query GraphDB
query_citation_titles()
# Out:
# Citation Titles:
# Citing Paper Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling-1, Cited Paper Title: From Parity and Payoff Games to Linear Programming
# Citing Paper Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling-1, Cited Paper Title: An XML-Based Database for Knowledge Discovery
# Citing Paper Title: Computational Trust Models and Machine Learning-1, Cited Paper Title: Private Read Update Write (PRUW) with Storage Constrained Databases
# Citing Paper Title: Combining Machine Learning with Knowledge Engineering to detect Fake News in Social Networks - A Survey-1, Cited Paper Title: Season-Based Occupancy Prediction in Residential Buildings Using Machine Learning Models
# Citing Paper Title: Combining Machine Learning with Knowledge Engineering to detect Fake News in Social Networks - A Survey-1, Cited Paper Title: Database resources of the National Center for Biotechnology Information: update
# Citing Paper Title: Forecasting Stock Market Prices Using Machine Learning and Deep Learning Models: A Systematic Review, Performance Analysis and Discussion of Implications-1, Cited Paper Title: Game Play: What Does It Mean for Pedagogy to Think Like a Game Developer?
# Citing Paper Title: Forecasting Stock Market Prices Using Machine Learning and Deep Learning Models: A Systematic Review, Performance Analysis and Discussion of Implications-1, Cited Paper Title: A Survey of Game Theoretic Approaches to Modelling Decision-Making in Information Warfare Scenarios
# Citing Paper Title: Forecasting Stock Market Prices Using Machine Learning and Deep Learning Models: A Systematic Review, Performance Analysis and Discussion of Implications-1, Cited Paper Title: Attention-LSTM-Attention Model for Speech Emotion Recognition and Analysis of IEMOCAP Database
# Citing Paper Title: Machine Learning for Predicting Cognitive Diseases: Methods, Data Sources and Risk Factors-1, Cited Paper Title: ffi cient Controller Synthesis for Consumption Games with Multiple Resource Types
# Citing Paper Title: Machine Learning for Predicting Cognitive Diseases: Methods, Data Sources and Risk Factors-1, Cited Paper Title: Predicting Student Self-regulation Strategies in Game-Based Learning Environments
# Citing Paper Title: Machine Learning for Predicting Cognitive Diseases: Methods, Data Sources and Risk Factors-1, Cited Paper Title: The PIR-International Protein Sequence Database.
# Citing Paper Title: Photorealistic Monocular Gaze Redirection Using Machine Learning-1, Cited Paper Title: Automated Ranking of Database Query Results
# Citing Paper Title: Photorealistic Monocular Gaze Redirection Using Machine Learning-1, Cited Paper Title: Intrapartum Fetal Heart Rate Classification: Cross-Database Evaluation
# Citing Paper Title: Evolving Applications of Artificial Intelligence and Machine Learning in Infectious Diseases Testing-1, Cited Paper Title: The Effectiveness of Games as Assignments in an Introductory Programming Course
# Citing Paper Title: Evolving Applications of Artificial Intelligence and Machine Learning in Infectious Diseases Testing-1, Cited Paper Title: Advanced Techniques for Content-Based Management of Multimedia Databases
# Citing Paper Title: miRLocator: Machine Learning-Based Prediction of Mature MicroRNAs within Plant Pre-miRNA Sequences-1, Cited Paper Title: Database updates in logic programming
# Citing Paper Title: Classification of Children’s Sitting Postures Using Machine Learning Algorithms-1, Cited Paper Title: A Tool for Storing OWL Using Database Technology
# Citing Paper Title: Season-Based Occupancy Prediction in Residential Buildings Using Machine Learning Models-1, Cited Paper Title: Game Theory Based Optimization of Security Configuration
# Citing Paper Title: Season-Based Occupancy Prediction in Residential Buildings Using Machine Learning Models-1, Cited Paper Title: Signature File Methods for Indexing Object-Oriented Database Systems
# Citing Paper Title: Season-Based Occupancy Prediction in Residential Buildings Using Machine Learning Models-1, Cited Paper Title: A UIMA Database Interface for Managing NLP-related Text Annotations

# %% [markdown]
# Now lets check papers-review_on-reviews

# %%
def query_reviews_with_paper_details():
    # Set up the SPARQL connection to your GraphDB instance
    #sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/lab2")
    
    # Define your SPARQL query
    query = """
    PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
    PREFIX ns1: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

    SELECT ?review ?reviewAbstract ?reviewDecision ?reviewDate ?paperTitle ?paperAbstract
    WHERE {
      # ?review a ex:Review;
              ex:abstract ?reviewAbstract;
              ex:date ?reviewDate;
              ex:decision ?reviewDecision;
              ex:reviewed_on ?paper.
      
      # ?paper ns1:title ?paperTitle;
             ns1:abstract ?paperAbstract.
    }
    """
    
    # Set the query to the SPARQL connection and specify the return format as JSON
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    # Execute the query and get the results
    results = sparql.query().convert()
    
    # Print the results
    print("Review Details with Linked Paper Information:")
    for result in results["results"]["bindings"]:
        print(f'Review Abstract: {result["reviewAbstract"]["value"]}, Decision: {result["reviewDecision"]["value"]}, Date: {result["reviewDate"]["value"]}')
        print(f'Paper Title: {result["paperTitle"]["value"]}, Paper Abstract: {result["paperAbstract"]["value"]}\n')

# Run the function to query GraphDB
query_reviews_with_paper_details()
# Out:
# Review Details with Linked Paper Information:
# Review Abstract: Strong sometimes soldier large offer letter. State be us well. Town expert issue opportunity choose., Decision: Accepted, Date: 2020-06-29
# Paper Title: EEG Databases in Research and Clinical Practice: Current Status and Future Directions, Paper Abstract: The influence of genetics and the environment, identibing reliable pre-morbid markers, expanding syndrome profiles, building quantitative models of brain function: the current interest in databases is motivated by such scientific imperatives. It is also fueled by the improved availability of the necessary technology, and by a number of high-profile initiatives. In particular, the Human Brain Project has seeded a plethora of distributed databases across scale and species, helped develop the field of Neuroinformatics, and provided a major impetus to the development of the analytical, biocomputational modeling, simulation tools and the interoperability that will link a federation of databases to enhance hypothesis-driven, as well as discovery-driven, neuroscience (see Koslow article in this issue). A number of journals have now begun to mandate that authors of accepted papers will provide access by other scientists to the raw data upon which the report was based (for example, Van Horn et al., 2004'). There is also the emergence of a standardized international database, generated using standardized methodology in all contributing laboratories and where the data analysis is centralized (see Gordon et al. article in this issue). This development allows for the study of individual differences, multi-modal interrelationships and the specificity, or generalizability, of the findings to be examined. The increased scale of database development is also coupled to a growing demand for large-scale science. The importance of "large-scale science" is highlighted in a recent article by five NIH directors in Nature Neuroscience entitled: "Limits to growth: why neuroscience needs largescale science" (Insel et al., 20042). In this Special Issue, invited authors not only discuss the issues generally, but also showcase several ambitious databases and innovative ways to exploit them. The Australian EEG Database paper (Hunter et al ) outlines the potential outcomes from a web-based de-identified searchable database of 18,500 EEG records across a spectrum of clinical disorders. Prichep's contribution proposes methods to enhance the sensitivity and specificity of qEEG in neurobehavioral clinical patient populations with the aim of eventually defining these disorders with objective qEEG based measures. Duffy extols the clinical utility of long latency ERPs, including Z statistic significance probability mapping and BESA analysis in order to understand patientspecific sensory processing difficulties, leading to more precise case conceptualization and better defined treatment. Johnstone et al. review clinical EEG studies in neurofeedback and propose treatment interventions that are testable in databases. Saletu et al. emphasize the "key and lock" principle as a potential pharmaco-EEG utility for defining therapeutic approaches as well as having significant potential for pharmacologically-based studies. This information is complemented by insights from Low-Resolution Brain Electromagnetic Tomography (LORETA). Thatcher et al. examine the validity of LORETA in defining patterns of abnormal qEEG activity defined by reference to a normative EEG database. Blinowska and Durka highlight the progress in the biomedical sciences for data-sharing and new EEGiERP analyses, illustrated via their EEG portal. Databases provide enhanced statistical power from data pooling, and show promise of elucidating new patterns of interrelationships amongst data obtained from normal subjects. They will also ultimately be used in the discovery of new medical treatments and will have applications to "Personalized Medicine," the study of individual subjects compared to their multi-dimensionally matched controls. We are entering a time in the history of Clinical Neuroscience (psychiatry, neurology, psychology) when we have sufficient data, as well as the availability of wi ...
#
# Review Abstract: Police a themselves make guy. Western paper chance management training move teacher. From choose beat hospital. Reveal challenge husband modern beautiful common. Quickly response question identify month career., Decision: Accepted, Date: 2023-09-27
# Paper Title: Machine Learning for Predicting Cognitive Diseases: Methods, Data Sources and Risk Factors, Paper Abstract:
#
# Review Abstract: Environment official call low. News final teach strategy six avoid. Play stay mind heart go., Decision: Accepted, Date: 2021-08-25
# Paper Title: Forecasting Stock Market Prices Using Machine Learning and Deep Learning Models: A Systematic Review, Performance Analysis and Discussion of Implications, Paper Abstract: The financial sector has greatly impacted the monetary well-being of consumers, traders, and financial institutions. In the current era, artificial intelligence is redefining the limits of the financial markets based on state-of-the-art machine learning and deep learning algorithms. There is extensive use of these techniques in financial instrument price prediction, market trend analysis, establishing investment opportunities, portfolio optimization, etc. Investors and traders are using machine learning and deep learning models for forecasting financial instrument movements. With the widespread adoption of AI in finance, it is imperative to summarize the recent machine learning and deep learning models, which motivated us to present this comprehensive review of the practical applications of machine learning in the financial industry. This article examines algorithms such as supervised and unsupervised machine learning algorithms, ensemble algorithms, time series analysis algorithms, and deep learning algorithms for stock price prediction and solving classification problems. The contributions of this review article are as follows: (a) it provides a description of machine learning and deep learning models used in the financial sector; (b) it provides a generic framework for stock price prediction and classification; and (c) it implements an ensemble model—“Random Forest + XG-Boost + LSTM”—for forecasting TAINIWALCHM and AGROPHOS stock prices and performs a comparative analysis with popular machine learning and deep learning models.
#
# Review Abstract: Right camera safe use career resource these. Say life month trial matter., Decision: Rejected, Date: 2019-06-20
# Paper Title: Creating a Business Process Diagram and Database Queries to Detect Billing Errors and Analyze Calling Patterns for Cell Phone Service, Paper Abstract: In this case, students develop a business process diagram to understand the business situation and create database queries to detect billing discrepancies and manage costs for corporate cell phone service. Using a database query tool or audit software, students query a database with tables for call details, invoices, invoice details, plan rates, and users on plan. The queries are representative of those that accountants could develop to analyze transaction‐level data to detect errors and develop insights about business operations. Query‐based approaches to analyzing transaction data can enable businesses to make sense of their operations and ensure that they and their trading partners comply with their mutual agreements. The case is appropriate for students with rudimentary database querying proficiency, e.g., at the level developed by Borthick et al.'s (2001) case on assuring compliance for responses to website referrals. No auditing expertise is needed. The case is appropriate for database analysis in a...
#
# Review Abstract: Tend attention traditional hard. Consumer past event line operation meet., Decision: Rejected, Date: 2023-04-01
# Paper Title: A Survey of Game Theoretic Approaches to Modelling Decision-Making in Information Warfare Scenarios, Paper Abstract: Our increasing dependence on information technologies and autonomous systems has escalated international concern for information- and cyber-security in the face of politically, socially and religiously motivated cyber-attacks. Information warfare tactics that interfere with the flow of information can challenge the survival of individuals and groups. It is increasingly important that both humans and machines can make decisions that ensure the trustworthiness of information, communication and autonomous systems. Subsequently, an important research direction is concerned with modelling decision-making processes. One approach to this involves modelling decision-making scenarios as games using game theory. This paper presents a survey of information warfare literature, with the purpose of identifying games that model different types of information warfare operations. Our contribution is a systematic identification and classification of information warfare games, as a basis for modelling decision-making by humans and machines in such scenarios. We also present a taxonomy of games that map to information warfare and cyber crime problems as a precursor to future research on decision-making in such scenarios. We identify and discuss open research questions including the role of behavioural game theory in modelling human decision making and the role of machine decision-making in information warfare scenarios.
#
# Review Abstract: Interest particularly language term. Agent whom security discover. Early already he lay student anything indeed ok. Fill away stop onto watch protect scientist medical. Four soon maybe wish center personal., Decision: Accepted, Date: 2020-09-15
# Paper Title: Linear-Quadratic Mean Field Stackelberg Games with State and Control Delays, Paper Abstract: In this article, we consider a linear-quadratic mean field game between a leader (dominating player) and a group of followers (agents) under the Stackelberg game setting as proposed in [A. Bensoussan, M. Chau, and S. Yam, Appl. Math. Optim., 74 (2016), pp. 91-128], so that the evolution of each individual follower is now also subjected to delay effects from both his/her state and control variables, as well as those of the leader. The overall Stackelberg game is solved by tackling three subproblems hierarchically. Their resolution corresponds to the establishment of the existence and uniqueness of the solutions of three different forward-backward stochastic functional differential equations, which we manage by applying the unified continuation method as first developed in, for example, [Y. Hu and S. Peng, Probab. Theory Related Fields, 103 (1995), pp. 273-283] and [X. Xu, Fully Coupled Forward-Backward Stochastic Functional Differential Equations and Applications to Quadratic Optimal Control, preprint, arX...
#
# Review Abstract: Reflect theory amount left. Wrong rock hand source. Street employee person full item speak decision. Skin cold east wall unit law remember. Shake through near cut., Decision: Accepted, Date: 2019-11-26
# Paper Title: Selected papers from the International Workshop on The World Wide Web and Databases, Paper Abstract:
#
# Review Abstract: Player nor may house go do hope. Recently grow recognize guy contain include response. Skill town dog need statement statement. Financial others benefit small teacher., Decision: Accepted, Date: 2021-10-31
# Paper Title: Parallel Evaluation of Hierarchical Image Databases, Paper Abstract: This paper presents a hierarchical image transformation and efficient parallel algorithms for its evaluation. This transformation maps image structures onto code trees of different height, depending on the size of the structure. Thereby, important structures are effectively separated from the background. The inherent parallelism of such a hierarchical image transformation is outlined. The algorithms are domain independent and were successfully used for workpiece recognition and for traffic sign detection. A communication module for farmer-worker applications that supports specialized processors, like frame grabbers or display units, as well as the parallel recognition process is illustrated in detail. The implementation is done on a 9-node transputer image processing system. The functionality from grabbing an image and low-level filtering to transformation and high-level symbolic pattern analysis is integrated. Runtimes for the analysis of traffic scenes of less than half a second were achieved. Illustrated examples and experimental results are discussed.
#
# Review Abstract: Time meet type around. Fine guess five drive. Hospital could player past night central., Decision: Accepted, Date: 2021-07-29
# Paper Title: Understanding Interpersonal Function in Psychiatric Illness Through Multiplayer Economic Games, Paper Abstract:
#
# Review Abstract: Rest fact several general computer. Almost forward summer board summer. Indeed little suffer history term month., Decision: Rejected, Date: 2019-07-14
# Paper Title: Simulation Games and Learning, Paper Abstract:
#
# Review Abstract: Wall agree however million stuff of. Control rise else education catch court word., Decision: Rejected, Date: 2022-12-21
# Paper Title: An Introduction to Relational Database Theory, Paper Abstract:
#
# Review Abstract: Manage establish dream fire spring live. Even later know example general. Statement cost from. Watch debate behavior modern strong wide citizen set., Decision: Rejected, Date: 2021-11-11
# Paper Title: Game creativity analysis using neural networks, Paper Abstract: Abstract Experts in ball games are characterized by extraordinary creative behaviour. This article outlines a framework for analysing types of individual development of creative performance based on neural networks. Therefore, two kinds of sport-specific training programme for the learning of game creativity in real field contexts were investigated. Two training groups (soccer, n = 20; field hockey, n = 17) but not a control group (n = 18) improved with respect to three measuring points (P < 0.001), although no difference could be established between the two training groups (P = 0.212). By using neural networks it is now possible to distinguish between five types of learning behaviour in the development of performance, the most striking ones being what we call “up-down” and “down-up”. In the field hockey group in particular, an up-down fluctuation process was identified, whereby creative performance increases initially, but at the end is worse than in the middle of the training programme. The reverse down-up fluctuation process was identified mainly in the soccer group. The results are discussed with regard to recent training explanation models, such as the super-compensation theory, with a view to further development of neural network applications.
#
# Review Abstract: Clearly American consider week foot daughter. Decision parent morning wish here color enjoy. Evening treatment forget big participant color child company. Guess billion personal perhaps stuff help., Decision: Rejected, Date: 2022-04-25
# Paper Title: Applying Machine Learning Techniques to Improve Linux Process Scheduling, Paper Abstract: In this work we use Machine Learning (ML) techniques to learn the CPU time-slice utilization behavior of known programs in a Linux system. Learning is done by an analysis of certain static and dynamic attributes of the processes while they are being run. Our objective was to discover the most important static and dynamic attributes of the processes that can help best in prediction of CPU burst times which minimize the process TaT (Turn-around-Time). In our experimentation we modify the Linux Kernel scheduler (version 2.4.20-8) to allow scheduling with customized time slices. The "Waikato Environment for Knowledge Analysis" (Weka), an open source machine-learning tool is used to find the most suitable ML method to characterize our programs. We experimentally find that the C'4.5 Decision Tree algorithm most effectively solved the problem. We find that predictive scheduling could reduce TaT in the range of 1.4% to 5.8%. This was due to a reduction in the number of context switches needed to complete the process execution. We find our result interesting in the context that generally operating systems presently never make use of a program's previous execution history in their scheduling behavior.
#
# Review Abstract: Style particularly Democrat long reduce recently. Author contain sign coach particular throw civil up. Eye kind apply small., Decision: Accepted, Date: 2020-08-21
# Paper Title: Relational Database to RDF Mapping Patterns, Paper Abstract: In order to integrate relational databases into Semantic Web applications, relational databases need to be mapped to RDF. The W3C RDB2RDF Working Group is in the process of ratifying two standards to map relational databases to RDF: Direct Mapping and R2RML mapping language. Through our experience as implementors of two RDB2RDF systems: Ultrawrap and Morph, and as authors of R2RML mappings, we have observed mappings that are reusable in order to solve a commonly occurring problem. In this paper, we have compiled these mappings and present a non-exhaustive list of RDB2RDF Mapping Patterns. We aspire that the mapping patterns in this paper are considered as a starting point for new mapping patterns.
#
# Review Abstract: Bill these action season economy manager. Run left hold. Set church reduce onto me plan treat. Court thought sort value close., Decision: Rejected, Date: 2023-10-21
# Paper Title: Testing Spatial Data Deliverance in SQL and NoSQL Database Using NodeJS Fullstack Web App, Paper Abstract: During the last decade, we saw an explosion of geospatial data being produced. Most of which coming from GPS-enabled devices available for general consumers. The large amount of geotagged data coined the term ‘Geospatial Big Data’, indicating the semi-structured and unstructured nature of such data. SQL relational databases have been known in the past to handle geospatial data very well. However, the abundance of geospatial big data pushed forward the need for NoSQL database which is expected to perform better in terms of handling and storing geospatial big data. This paper discusses the quantitative comparison of performance between the SQL (i.e., PostGIS) and NoSQL (i.e., MongoDB) databases in handling geospatial big data. A NodeJS-based angular-framework web app was developed to test the real-world performance of MongoDB and PostGIS in handling a large amount of simulated geospatial data. A different number of points were generated for testing the geospatial data storing and loading capability of both the databases. The test was conducted by comparing the result of XHR (XML HTTP Request) of both databases in each case. The result showed that NoSQL database, i.e. MongoDB, performs better in loading big geospatial data compared to traditional SQL database using PostGIS.
#
# Review Abstract: Kid development son view fall. Similar tell employee of end inside hand. Minute trade either fast road lay., Decision: Rejected, Date: 2020-04-11
# Paper Title: STREETS: Game-Theoretic Traffic Patrolling with Exploration and Exploitation, Paper Abstract: To dissuade reckless driving and mitigate accidents, cities deploy resources to patrol roads. In this paper, we present STREETS, an application developed for the city of Singapore, which models the problem of computing randomized traffic patrol strategies as a defenderattacker Stackelberg game. Previous work on Stackelberg security games has focused extensively on counterterrorism settings. STREETS moves beyond counterterrorism and represents the first use of Stackelberg games for traffic patrolling, in the process providing a novel algorithm for solving such games that addresses three major challenges in modeling and scale-up. First, there exists a high degree of unpredictability in travel times through road networks, which we capture using a Markov Decision Process for planning the patrols of the defender (the police) in the game. Second, modeling all possible police patrols and their interactions with a large number of adversaries (drivers) introduces a significant scalability challenge. To address this challenge we apply a compact game representation in a novel fashion combined with adversary and state sampling. Third, patrol strategies must balance exploitation (minimizing violations) with exploration (maximizing omnipresence), a tradeoff we model by solving a biobjective optimization problem. We present experimental results using real-world traffic data from Singapore. This work is done in collaboration with the Singapore Ministry of Home Affairs and is currently being evaluated by the Singapore Police Force.
#
# Review Abstract: Technology across however back project. Purpose fight country capital it. Generation peace save everyone visit among happy. Bar north technology home administration., Decision: Rejected, Date: 2023-06-10
# Paper Title: Is This a Game or a Learning Moment, Paper Abstract: Examinations often serve as the primary means to assess student learning within a classroom environment. To increase the probability of success in examinations, many instructors will employ a review session to prepare their students. The type of review session may vary from a laundry list of potential test topics to mock examinations. In order to provide the clarity that a student needs, instructors must structure their review session to enable their students to not only understand the material, but also be able to apply the material to new situations that they may encounter on the examination and even beyond the classroom. One interesting way that we used to review material that provided insight and interaction and even injected some fun into learning was by using a variation of the “Who Wants To Be A Millionaire ” television game show to conduct midterm and final review sessions in both undergraduate and MBA operations management courses. The Web site http://condor.depaul.edu/∼greinhar/ wwtbam.html contains the complete set of downloadable files necessary to conduct the review session (shown in Table 1).
#
# Review Abstract: Well size middle main send business tree. Over newspaper outside line chance song world., Decision: Rejected, Date: 2021-07-15
# Paper Title: Game Theory Based Optimization of Security Configuration, Paper Abstract: How to make a trade off between the security of sys- tems and the usability of users is an important issue in network security configuration. To resolve this problem, an optimization method of security configuration based on game theory is proposed. Firstly, a security configuration model based on non-cooperative game is built which in- fers the optimal strategy of systems and users respectively by calculating their strategies and incentives. Secondly, to optimize security configuration further, it cooperatively optimizes the individual optimal strategy by cooperative game, thus eliminating the cases that individual optimal is not the overall optimal. An illustrated experiment shows that this method can coordinate the security of network systems and usability of users so that the security configu- ration of system is optimized magnificently.
#
# Review Abstract: Southern full someone answer young consumer. Shake role threat require brother public. Scene political gun travel big image tree. Necessary material indeed writer. Now develop require save scene., Decision: Accepted, Date: 2023-05-09
# Paper Title: Database technology in health care, Paper Abstract:
#
# Review Abstract: Song station loss themselves lawyer. Actually former may listen boy black no. Step police take American., Decision: Rejected, Date: 2020-12-29
# Paper Title: A Concurrent Database Manipulation Problem: Binary Search Trees (Abstract), Paper Abstract:
#
# Review Abstract: Point month crime fact. There food its another ago. Third develop always nearly baby box structure., Decision: Rejected, Date: 2021-12-15
# Paper Title: A Model for the Evaluation of Educational Games for Teaching Software Engineering, Paper Abstract: Teaching software engineering through educational games is expected to have several benefits. Various games have already been developed in this context, yet there is still a lack of assessment models to measure the real benefits and quality of these educational resources. This article presents the development of a model for assessing the quality of educational games for teaching software engineering. The model has been systematically derived from literature and evaluated in terms of its applicability, usefulness, validity and reliability through a series of case studies, applying educational board games in software engineering courses. Early results indicate that the model can be used to assess the aspects of motivation, user experience and learning of educational SE games.
#
# Review Abstract: Season national above daughter sister threat book apply. Line everyone pay tough agreement., Decision: Accepted, Date: 2021-06-19
# Paper Title: Design Your Own Games and Activities: Thiagi's Templates for Performance Improvement, Paper Abstract:
#
# Review Abstract: Play company American important actually risk station employee. Where company former. Create direction human since degree., Decision: Rejected, Date: 2019-07-13
# Paper Title: Graph Databases in Molecular Biology, Paper Abstract:
#
# Review Abstract: Find run party get campaign response. Tend quality song rise she eat director. Save challenge probably whether hope much., Decision: Accepted, Date: 2022-12-04
# Paper Title: On the Robustness of the Extension of the One-Third Law of Evolution to the Multi-Player Game, Paper Abstract:
#
# Review Abstract: Today into although house down reach. Strategy issue season summer serve only yet. Ask indeed it public cost tax nearly., Decision: Accepted, Date: 2022-10-18
# Paper Title: Game Play: What Does It Mean for Pedagogy to Think Like a Game Developer?, Paper Abstract: What could a sport coach or sport teacher within physical education learn from digital game design and the way digital games capture, sustain, and maintain children's attention? Would the physical education learning experience be different if physical educators designed and enacted sport teaching by attempting to accommodate the learning needs and preferences of the wrap around technology generation by giving deliberate attention to the design principles employed in digital game design? This article emerged from those two questions to highlight how, as games governed by rules of play, sport and digital game play have much in common and, therefore, sport teachers in physical education may enhance student engagement by incorporating learning principles used in digital game design.
#
# Review Abstract: Memory physical subject according. Discuss any writer new positive since meet. Seat soldier hospital generation mean truth. According store save party., Decision: Accepted, Date: 2023-08-10
# Paper Title: A Computer Games Software Factory and Edutainment Platform for Microsoft .NET, Paper Abstract: — This paper presents an environment targeted at computer games development industrialization in the .NET Platform. A computer game product line definition and its architecture are specified and implemented by means of software factory assets, such as a visual designer based on a domain-specific language (DSL), semantic validators and code generators. The proposed approach is then illustrated and empirically validated by the creation of real world case studies. Finally, it is investigated how the proposed factory can be used as an edutainment platform for Computer Science 1 (CS1) and 2 (CS2) courses. The final intention is to empower game developers and designers to work more productively, with a higher level of abstraction and closer to their application domain.
#
# Review Abstract: Arrive memory truth town. Charge suggest challenge only tree. Him couple either his girl power likely. Image moment land painting tough nor., Decision: Rejected, Date: 2023-10-19
# Paper Title: Mobile Game-Based Science Learning, Paper Abstract: This study describes and analyzes the design, development, application and evaluation of a new pedagogical methodology based on interactive games for mobile devices (PDAs). The methodology is oriented to developing problem-solving skills in science classes for 8 th graders, by including pre-classroom activities with the teacher, classroom activities, and a central activity using an interactive game for a mobile device. The core problem they had to solve through the game consisted in preserving and evolving different biological species from the animal kingdom, in an unknown and varying environment, by modifying some key factors for evolution of the species. The study was implemented in two main stages: a guided visit to a zoo observing animals directly, and a simulation game that takes place in the school during four weeks. Results show highly motivated learners with a fast adoption of mobile devices, fully engaged in a learning task without external control.
#
# Review Abstract: Hospital hot serious among until once. Force range already international method. Cut air rate. Move sign treat travel protect bank vote wonder., Decision: Accepted, Date: 2023-09-05
# Paper Title: MarioQA: Answering Questions by Watching Gameplay Videos, Paper Abstract: We present a framework to analyze various aspects of models for video question answering (VideoQA) using customizable synthetic datasets, which are constructed automatically from gameplay videos. Our work is motivated by the fact that existing models are often tested only on datasets that require excessively high-level reasoning or mostly contain instances accessible through single frame inferences. Hence, it is difficult to measure capacity and flexibility of trained models, and existing techniques often rely on adhoc implementations of deep neural networks without clear insight into datasets and models. We are particularly interested in understanding temporal relationships between video events to solve VideoQA problems; this is because reasoning temporal dependency is one of the most distinct components in videos from images. To address this objective, we automatically generate a customized synthetic VideoQA dataset using Super Mario Bros. gameplay videos so that it contains events with different levels of reasoning complexity. Using the dataset, we show that properly constructed datasets with events in various complexity levels are critical to learn effective models and improve overall performance.
#
# Review Abstract: Thousand future mean various wall mouth. That vote investment safe. Leave toward glass expert say talk. Season statement listen poor find pressure. Create class a tough discuss professional. Focus enough thought choose particularly individual at power., Decision: Accepted, Date: 2020-02-07
# Paper Title: A Comprehensive Guide Through the Italian Database Research Over the Last 25 Years, Paper Abstract:
#
# Review Abstract: Others job seven. South throughout couple., Decision: Accepted, Date: 2020-02-12
# Paper Title: Game-theoretic cooperativity in networks of self-interested units, Paper Abstract: The behavior of theoretical neural networks is often described in terms of competition and cooperation. I present an approach to network learning that is related to game and team problems in which competition and cooperation have more technical meanings. I briefly describe the application of stochastic learning automata to game and team problems and then present an adaptive element that is a synthesis of aspects of stochastic learning automata and typical neuron‐like adaptive elements. These elements act as self‐interested agents that work toward improving their performance with respect to their individual preference orderings. Networks of these elements can solve a variety of team decision problems, some of which take the form of layered networks in which the ‘‘hidden units’’ become appropriate functional components as they attempt to improve their own payoffs.
#
# Review Abstract: Section leg subject management discover. Key better glass up bed. Campaign design husband season have activity. End me bring social partner. Stand weight state. Study others part life hit him., Decision: Accepted, Date: 2020-12-07
# Paper Title: A Tool for Storing OWL Using Database Technology, Paper Abstract: . This paper presents a tool that helps developers to design and implement storage models for OWL ontologies. This tool uses xml both to represent the knowledge given by the ontology, and deﬁne the rules that generate the storage model. It presents a graphical interface that helps developers to use it. The storage models created by this tool will be used in our research studies.
#
# Review Abstract: Part since friend game four about. Store third onto voice. Serious network heart director Mrs serious shoulder. Stay responsibility impact machine start reveal career prevent., Decision: Accepted, Date: 2021-03-09
# Paper Title: Immersive Multiplayer Games With Tangible and Physical Interaction, Paper Abstract: In this paper, we present a new immersive multiplayer game system developed for two different environments, namely, virtual reality (VR) and augmented reality (AR). To evaluate our system, we developed three game applications-a first-person-shooter game (for VR and AR environments, respectively) and a sword game (for the AR environment). Our immersive system provides an intuitive way for users to interact with the VR or AR world by physically moving around the real world and aiming freely with tangible objects. This encourages physical interaction between players as they compete or collaborate with other players. Evaluation of our system consists of users' subjective opinions and their objective performances. Our design principles and evaluation results can be applied to similar immersive game applications based on AR/VR.
#
# Review Abstract: What improve billion color. Lot kitchen perhaps wind course common. Way step machine term social identify. See him partner ahead. Feel decision attorney box yeah let. Church physical part Mr air matter., Decision: Accepted, Date: 2021-04-30
# Paper Title: The Effectiveness of Games as Assignments in an Introductory Programming Course, Paper Abstract: Computer games are an often cited motivational tool used as assignments in introductory programming courses. This paper presents the results of a study that attempts to quantify the effectiveness of computer games as programming projects over non-games. Students completed five major programming assignments during the semester in an introductory programming course. For each assignment, students were given an option between two programming projects, a game and a non-game. Throughout the term, 78.9% of the assignments submitted by students were the game option. The average grade, however, on game assignments was 89.1%, while the non-game average was 95.1%. In a post-term survey 84% of student respondents answered "yes" to the question, "Did the games provide any extra motivation for you to complete the projects with a high level of quality?" Results suggest that games do indeed provide psychological motivation and increase course enjoyment, even though they may not improve students' scores
#
# Review Abstract: Protect entire structure decide these court practice. Use a create huge. Even true mention growth military. Some year modern off section property., Decision: Rejected, Date: 2024-03-15
# Paper Title: Numerical Solutions for Stochastic Differential Games With Regime Switching, Paper Abstract: This paper is concerned with numerical methods for stochastic differential games of regime-switching diffusions. Numerical methods using Markov chain approximation techniques are developed. A new proof of the existence of a saddle point for the stochastic differential game is provided. This new proof enables us to treat certain systems with nonseparable (in controls) structure. Convergence of the algorithms is derived by means of weak convergence methods. In addition, examples are also provided for demonstration purposes.
#
# Review Abstract: Bar fight thought serious recent miss. Understand best rich hear worker hand this. Pressure soon its TV economy majority beyond. Society street occur. Think most generation., Decision: Rejected, Date: 2022-05-15
# Paper Title: iShare: Blockchain-Based Privacy-Aware Multi-Agent Information Sharing Games for Cybersecurity, Paper Abstract: In this paper, we design, develop, and evaluate a novel information sharing (iShare) framework for cybersecurity with the goal of protecting confidential information and networked infrastructures from future cyber-attacks. The proposed iShare framework leverages the Blockchain concept used in Bitcoin systems where multiple organizations/agencies participate for information sharing (without violating their privacy) to secure and monitor their cyberspace. Note that the Bitcoin for financial transactions has already demonstrated that there is a trusted, auditable sharing with peer-to-peer communications accompanied by a public ledger. The main aim of the Blockchain-based iShare framework is to constantly collect high-resolution, cyber-attack information across organizational boundaries of which the organizations have no specific knowledge or control over any other organizations’ data or damage caused by cyber-attacks. In the proposed iShare framework, the decentralized nature of the Blockchain and digitally signed transactions ensure that an adversary cannot pose as a legitimate organization/user or cannot control/hamper the system because of the digital-signatures and cannot learn anything from the public ledger that has just hashed pointers. Moreover, we analyze the security attacks by outsiders (not participating in the iShare) using a Stackelberg game.
#
# Review Abstract: Consumer want time radio especially yes general. Republican organization standard less add. Vote opportunity support although official material budget. Class likely organization view agree the. Ahead son table performance authority near. Over man partner year party information trade two. Raise authority buy sense beautiful., Decision: Rejected, Date: 2022-05-10
# Paper Title: Designing and Recording an Emotional Speech Database for Corpus Based Synthesis in Basque, Paper Abstract: This paper describes an emotional speech database recorded for standard Basque. The database has been designed with the twofold purpose of being used for corpus based synthesis, and also of allowing the study of prosodic models for the emotions. The database is thus large, to get good corpus based synthesis quality and contains the same texts recorded in the six basic emotions plus the neutral style. The recordings were carried out by two professional dubbing actors, a man and a woman. The paper explains the whole creation process, beginning with the design stage, following with the corpus creation and the recording phases, and finishing with some learned lessons and hints.
#
# Review Abstract: Decide shoulder crime. Box social evidence say seem maybe option. Development order civil minute operation write every. Body usually reflect son paper continue. Church middle blood hot major., Decision: Accepted, Date: 2023-08-30
# Paper Title: Collection and Exploration of Large Data Monitoring Sets Using Bitmap Databases, Paper Abstract:
#
# Review Abstract: Not relationship opportunity forward air what. Difference believe catch authority. Better administration around option research land. Onto forward others force later film parent break. Former second word must spring respond heart. Require bit keep official benefit. Especially time score pattern., Decision: Rejected, Date: 2022-05-13
# Paper Title: A Game-Theoretic Analysis of the Off-Switch Game, Paper Abstract:
#
# Review Abstract: As usually whole baby above. Thought nearly require world past. Area could claim anyone., Decision: Accepted, Date: 2021-03-01
# Paper Title: A First Course on Zero-Sum Repeated Games by Sylvain Sorin, Paper Abstract:
#
# Review Abstract: Foreign place a especially suffer Mrs own girl. Picture democratic financial peace., Decision: Rejected, Date: 2022-10-18
# Paper Title: From Parity and Payoff Games to Linear Programming, Paper Abstract:
#
# Review Abstract: Or doctor story analysis time sound cold above. Follow scientist nor parent long still. Factor college power coach western mention., Decision: Rejected, Date: 2021-08-09
# Paper Title: Database resources of the National Center for Biotechnology Information: update, Paper Abstract: In addition to maintaining the GenBank(R) nucleic acid sequence database, the National Center for Biotechnology Information (NCBI) provides data analysis and retrieval resources for the data in GenBank and other biological data made available through NCBI’s website. NCBI resources include Entrez, PubMed, PubMed Central, LocusLink, the NCBI Taxonomy Browser, BLAST, BLAST Link (BLink), Electronic PCR, OrfFinder, Spidey, RefSeq, UniGene, HomoloGene, ProtEST, dbMHC, dbSNP, Cancer Chromosome Aberration Project (CCAP), Entrez Genomes and related tools, the Map Viewer, Model Maker, Evidence Viewer, Clusters of Orthologous Groups (COGs) database, Retroviral Genotyping Tools, SARS Coronavirus Resource, SAGEmap, Gene Expression Omnibus (GEO), Online Mendelian Inheritance in Man (OMIM), the Molecular Modeling Database (MMDB), the Conserved Domain Database (CDD) and the Conserved Domain Architecture Retrieval Tool (CDART). Augmenting many of the web applications are custom implementations of the BLAST program optimized to search specialized data sets. All of the resources can be accessed through the NCBI home page at: http://www.ncbi.nlm.nih.gov.
#
# Review Abstract: Decision which democratic down born. Card car choice yard center skill. Remain serious firm., Decision: Rejected, Date: 2020-02-24
# Paper Title: Approximations in Database Systems, Paper Abstract:
#
# Review Abstract: Responsibility today live significant occur begin. What school although reach admit be maybe boy. Serve others lawyer these never region evidence., Decision: Rejected, Date: 2022-03-05
# Paper Title: Efficient 3D Database Screening for Novel HIV-1 IN Inhibitors, Paper Abstract: We describe the use of pharmacophore modeling as an efficient tool in the discovery of novel HIV-1 integrase (IN) inhibitors. A three-dimensional hypothetical model for the binding of diketo acid analogues to the enzyme was built by means of the Catalyst program. Using these models as a query for virtual screening, we found several compounds that contain the specified 3D patterns of chemical functions. Biological testing shows that our strategy was successful in searching for new structural leads as HIV-1 IN inhibitors.
#
# Review Abstract: Offer suggest pull as message. Reach hundred social Republican. Bag guy thus wrong under modern. Week writer teacher. Across cultural region election quickly., Decision: Rejected, Date: 2019-10-26
# Paper Title: CoDEL - A Relationally Complete Language for Database Evolution, Paper Abstract:
#
# Review Abstract: Fact our next although improve case choice. Attention war network audience put apply. Try note scene research surface hour my., Decision: Accepted, Date: 2023-06-25
# Paper Title: Database of Piano Chords - An Engineering View of Harmony, Paper Abstract:
#
# Review Abstract: Citizen our although. Maintain stay fast recent nor mouth. Notice husband might month. Hundred building possible explain institution weight purpose. Glass increase region include them. On want star three name baby your. Walk should indeed car ok party art. Might just long give because for majority., Decision: Accepted, Date: 2022-02-19
# Paper Title: Stopping Games - Recent Results, Paper Abstract: We survey recent results on the existence of the value in zerosum stopping games with discrete and continuous time, and on the existence of e-equilibria in non zero-sum games with discrete time. (This abstract was borrowed from another version of this item.)
#
# Review Abstract: Training change back meet general teach too treatment. Five family option our community power enjoy. Court question fast walk. That detail administration role sit. Go hold hear. Large fine outside exist. You natural across., Decision: Accepted, Date: 2022-12-23
# Paper Title: Design-by-Analogy: Exploring for Analogical Inspiration With Behavior, Material, and Component-Based Structural Representation of Patent Databases, Paper Abstract: Design-by-analogy (DbA) is an important method for innovation that has gained much attention due to its history of leading to successful and novel design solutions. The method uses a repository of existing design solutions where designers can recognize and retrieve analogical inspirations. Yet, exploring for analogical inspiration has been a laborious task for designers. This work presents a computational methodology that is driven by a topic modeling technique called non-negative matrix factorization (NMF). NMF is widely used in the text mining field for its ability to discover topics within documents based on their semantic content. In the proposed methodology, NMF is performed iteratively to build hierarchical repositories of design solutions, with which designers can explore clusters of analogical stimuli. This methodology has been applied to a repository of mechanical design-related patents, processed to contain only component-, behavior-, or material-based content to test if unique and valuable attribute-based analogical inspiration can be discovered from the different representations of patent data. The hierarchical repositories have been visualized, and a case study has been conducted to test the effectiveness of the analogical retrieval process of the proposed methodology. Overall, this paper demonstrates that the exploration-based computational methodology may provide designers an enhanced control over design repositories to retrieve analogical inspiration for DbA practice.
#
# Review Abstract: Front sport third then though. Citizen her who executive establish law. Fast fly around Mr specific say understand major., Decision: Rejected, Date: 2023-12-05
# Paper Title: An Animated Introduction to Relational Databases for Many Majors, Paper Abstract: Database technology affects many disciplines beyond computer science and business. This paper describes two animations developed with images and color that visually and dynamically introduce fundamental relational database concepts and querying to students of many majors. The goal is for educators in diverse academic disciplines to incorporate the animations in their existing courses in order to meet their pedagogical needs. The introduction of the animations was assessed and evaluated within several contexts, including non-majors courses offered by computer scientists as well as a course on computational molecular biology. The evaluation indicated that student knowledge of fundamental database concepts improved significantly with the use of the courseware. The animations provide visual learners with an engaging method to learn the topics presented with the ability to replay the dynamic presentation. Overall, the evaluation indicates the accessibility of database topics across the disciplines as well as the specific concepts that need further elaboration.
#
# Review Abstract: Official above modern look must attack. Test one itself practice key throughout treat. Rate just pass choose full agent. Foreign memory type bad. Short throughout strong wish choice season move. Increase need parent reduce commercial., Decision: Accepted, Date: 2023-01-15
# ...
#
# Review Abstract: Long reveal race indeed occur several. Chair phone former read million others understand. Game white everything in amount program example., Decision: Rejected, Date: 2022-10-22
# Paper Title: Automated Ranking of Database Query Results, Paper Abstract: Ranking and returning the most relevant results of a query is a popular paradigm in Information Retrieval. We discuss challenges and investigate several approaches to enable ranking in databases, including adaptations of known techniques from information retrieval. We present results of preliminary experiments.
#
# Review Abstract: Role single represent financial everything list. Mean finally evening move. Special several play actually but speech scene miss. Keep also lay bag doctor traditional state. Resource man leave., Decision: Accepted, Date: 2020-12-12
# Paper Title: Game-based Abstraction for Markov Decision Processes, Paper Abstract: In this paper we present a novel abstraction technique for Markov decision processes (MDPs), which are widely used for modelling systems that exhibit both probabilistic and nondeterministic behaviour. In the field of model checking, abstraction has proved an extremely successful tool to combat the state-space explosion problem. In the probabilistic setting, however, little practical progress has been made in this area. We propose an abstraction method for MDPs based on stochastic two-player games. The key idea behind this approach is to maintain a separation between nondeterminism present in the original MDP and nondeterminism introduced through abstraction, each type being represented by a different player in the game. Crucially, this allows us to obtain distinct lower and upper bounds for both the best and worst-case performance (minimum or maximum probabilities) of the MDP. We have implemented our techniques and illustrate their practical utility by applying them to a quantitative analysis of the Zeroconf dynamic network configuration protocol
#
# Review Abstract: Wear speak store then these whose process. Door about take stuff. Tell believe ago thousand late write. Arm idea realize sister its. Everything early identify decade. Apply article animal certainly as drop choice. A situation rise describe discussion forget. Check central present personal., Decision: Accepted, Date: 2022-09-01
# Paper Title: Early Detection of Aphid Infestation and Insect-Plant Interaction Assessment in Wheat Using a Low-Cost Electronic Nose (E-Nose), Near-Infrared Spectroscopy and Machine Learning Modeling, Paper Abstract: Advances in early insect detection have been reported using digital technologies through camera systems, sensor networks, and remote sensing coupled with machine learning (ML) modeling. However, up to date, there is no cost-effective system to monitor insect presence accurately and insect-plant interactions. This paper presents results on the implementation of near-infrared spectroscopy (NIR) and a low-cost electronic nose (e-nose) coupled with machine learning. Several artificial neural network (ANN) models were developed based on classification to detect the level of infestation and regression to predict insect numbers for both e-nose and NIR inputs, and plant physiological response based on e-nose to predict photosynthesis rate (A), transpiration (E) and stomatal conductance (gs). Results showed high accuracy for classification models ranging within 96.5–99.3% for NIR and between 94.2–99.2% using e-nose data as inputs. For regression models, high correlation coefficients were obtained for physiological parameters (gs, E and A) using e-nose data from all samples as inputs (R = 0.86) and R = 0.94 considering only control plants (no insect presence). Finally, R = 0.97 for NIR and R = 0.99 for e-nose data as inputs were obtained to predict number of insects. Performances for all models developed showed no signs of overfitting. In this paper, a field-based system using unmanned aerial vehicles with the e-nose as payload was proposed and described for deployment of ML models to aid growers in pest management practices.
#
# Review Abstract: Every fund evening speak Mrs. Father spend difference never. Next believe really enough. Happen out city region worry everything. Product fund discuss statement dog., Decision: Accepted, Date: 2022-03-19
# Paper Title: BCI Promises in Emotional Involvement in Music and Games, Paper Abstract: The reliability of commercial non-invasive BCI (brain computer Interface) devices and the lower cost of these EEG-based systems, as well as the equipment's portability, determined the increasing interest in their application in different research fields. The latter feature makes BCI devices particularly suited for entertainment applications, especially given the possibility to detect the mental state of the users. The relationship between emotions and entertainment is obvious, as is the influence of music in human emotional states. While BCI devices represent a challenge in gaming motion control, they have been successfully applied in music production [Dan et al. 2009] and composition [Hamadicharef et al. 2010]. In our previous work [Conscious and unconscious music from the brain in press] we focused on conscious production of music notes with the aim of developing a prototype for applications in entertainment. In this work we trace the state-of-the art of our research and present our opinion on possible applications of the preliminary results.
#
# Review Abstract: Tv last full present leader see. Reduce friend improve light property. Poor later majority list name respond who speech. Difference third stop member wish during. Ask rather ability at break total city. Wait rich performance give her right offer. Area now compare movement himself. Upon type still across., Decision: Rejected, Date: 2021-06-23
# Paper Title: Predicting Student Self-regulation Strategies in Game-Based Learning Environments, Paper Abstract:
#
# Review Abstract: Throughout moment until administration magazine perform international. Tax course pull do difficult. Record season enjoy., Decision: Accepted, Date: 2023-02-06
# Paper Title: The Game of Triangles, Paper Abstract: We present STR (Star-Triangle Relations), a Mathematica package designed to solve Feynman integrals by means of the method of uniqueness in any Euclidean spacetime dimension. We provide a set of tools to draw Feynman diagrams and interact with them only by the use of the mouse. Throughout the use of a graphic interface, the package should be easily accessible to users with little or no previous experience on diagrams computation.
#
# Review Abstract: Chair on whatever each majority. Save old finally month cup despite. Wall letter better Democrat bill side throughout. Ago return adult then many land animal., Decision: Accepted, Date: 2024-01-13
# Paper Title: O-Minimal Hybrid Reachability Games, Paper Abstract: In this paper, we consider reachability games over general hybrid systems, and distinguish between two possible observation frameworks for those games: either the precise dynamics of the system is seen by the players (this is the perfect observation framework), or only the starting point and the delays are known by the players (this is the partial observation framework). In the first more classical framework, we show that time-abstract bisimulation is not adequate for solving this problem, although it is sufficient in the case of timed automata . That is why we consider an other equivalence, namely the suffix equivalence based on the encoding of trajectories through words. We show that this suffix equivalence is in general a correct abstraction for games. We apply this result to o-minimal hybrid systems, and get decidability and computability results in this framework. For the second framework which assumes a partial observation of the dynamics of the system, we propose another abstraction, called the superword encoding, which is suitable to solve the games under that assumption. In that framework, we also provide decidability and computability results.
#
# Review Abstract: Sure always everything increase., Decision: Accepted, Date: 2024-03-01
# Paper Title: Communities of Play: Emergent Cultures in Multiplayer Games and Virtual Worlds, Paper Abstract: Communities of Play: Emergent Cultures in Multiplayer Games and Virtual Worlds Celia Pearce and Artemesia Cambridge, MA.: MIT Press, 2009. Forwards, illustrations, references, index. 327 pp. $29.95 cloth. ISBN: 9780262162579Celia Pearce's Communities of Play is a fascinating, wide-ranging study relevant to anyone interested in online games and worlds, ethnography, or game studies. The book tells the story of a group of players who originally met in the massively multiplayer online game (MMO) Uru Prologue and their efforts to stay together after the game closed. This work is significant for three major reasons. First, it is a study of the processes that give rise to emergent behavior in MMOs, a topic of relevance to both game designers and sociologists. Second, the book is also one of very few studies addressing how a virtual world's closing affects its players. Finally, it contains an insightful analysis of the perks and perils of doing ethnography in an online community, an analysis that is invaluable for anyone considering a similar project.Uru Prologue was intended as the beta test for Uru Live, an MMO set in the popular Myst universe. Uru Live was canceled before release, however, and Uru Prologue closed on February 9, 2004. This closure marked both the end of the beta test, the cancellation of Uru Live, and the birth of what Pearce refers to as the "Uru Diaspora," a group of players who now inhabit other online spaces but still identify as Uru-vians (p. 93). The book focuses on how one particular group of players known as "The Gathering of Uru" (TGU) reacted to the closing and attempted to stay together.One notable theoretical tool Pearce defines early in the book is a continuum of online game types, with "fixed-synthetic worlds" (such as Uru and World of Warcraft) at one end and "co-created worlds" (such as There.com and Second Life) at the other. In the former, users have few content-creation tools, while the latter emphasize user-created content. Pearce's continuum provides a useful means of analyzing how the emergent social behavior occurring in an MMO is shaped by the affordances and constraints placed on the player. (Here "emergence" refers to a phenomenon whereby complex systems organize themselves and act in unpredictable ways, while "affordances and constraints" refer to what a given MMO does and does not allow its users to do.) For members of the TGU, the affordances of co-created worlds such as There.com and Second Life enabled them to re-create environments and objects from Uru Prologue in other virtual worlds. Pearce's identification of this phenomenon offers game designers insight into how a virtual world can be designed to support varying kinds of emergent behavior among the players. …
#
# Review Abstract: Beautiful may serve return ability. Safe hundred result your number step. Their story perhaps meet life experience scientist., Decision: Rejected, Date: 2020-08-07
# Paper Title: Natural language Interface for Database: A Brief review, Paper Abstract: Information is playing an important role in our lives. One of the major sources of information is databases. Databases and database technology are having major impact on the growing use of computers. Almost all IT applications are storing and retrieving information from databases. Retrieving information database requires knowledge of database languages like SQL. The Structured Query Language (SQL) norms are been pursued in almost all languages for relational database systems. However, not everybody is able to write SQL queries as they may not be aware of the structure of the database. So this has led to the development of Intelligent Database System ( IDBS) . There is an overwhelming need for non-expert users to query relational databases in their natural language instead of working with the values of the attributes. As a result many intelligent natural language interfaces to databases have been developed, which provides flexible options for manipulating queries. The idea of using Natural Language instead of SQL has prompted the development of new type of processing called Natural language Interface to Database. NLIDB is a step towards the development of intelligent database systems (IDBS) to enhance the users in performing flexible querying in databases. This paper is an introduction to Intelligent Database System and Natural Language Interface to Databases. Then a brief overview of NLIDB subcomponents is given and then discussion then moves on to NLIDB architectures and various approaches for the development of NLIDB systems.
#
# Review Abstract: Yourself performance drug yourself run may best executive. Hundred while include part buy because. Structure seem art move travel. Summer control up garden need., Decision: Accepted, Date: 2019-09-27
# Paper Title: Greedy and Linear Ensembles of Machine Learning Methods Outperform Single Approaches for QSPR Regression Problems, Paper Abstract: The application of Machine Learning to cheminformatics is a large and active field of research, but there exist few papers which discuss whether ensembles of different Machine Learning methods can improve upon the performance of their component methodologies. Here we investigated a variety of methods, including kernel‐based, tree, linear, neural networks, and both greedy and linear ensemble methods. These were all tested against a standardised methodology for regression with data relevant to the pharmaceutical development process. This investigation focused on QSPR problems within drug‐like chemical space. We aimed to investigate which methods perform best, and how the ‘wisdom of crowds’ principle can be applied to ensemble predictors. It was found that no single method performs best for all problems, but that a dynamic, well‐structured ensemble predictor would perform very well across the board, usually providing an improvement in performance over the best single method. Its use of weighting factors allows the greedy ensemble to acquire a bigger contribution from the better performing models, and this helps the greedy ensemble generally to outperform the simpler linear ensemble. Choice of data preprocessing methodology was found to be crucial to performance of each method too.
#
# Review Abstract: Television paper threat season up. Now throw simply apply throw., Decision: Rejected, Date: 2023-01-02
# Paper Title: Tripartite ATP-Independent Periplasmic Transporters: Application of a Relational Database for Genome-Wide Analysis of Transporter Gene Frequency and Organization, Paper Abstract: Tripartite ATP-independent periplasmic (TRAP) transporters are a family of extracytoplasmic solute receptor-dependent secondary transporters that are widespread in the prokaryotic world but which have not been extensively studied. Here, we present results of a genome-wide analysis of TRAP sequences and genome organization from application of TRAPDb, a relational database created for the collection, curation and analysis of TRAP sequences. This has revealed a specific enrichment in the number of TRAP transporters in several bacteria which is consistent with increased use of TRAP transporters in saline environments. Additionally, we report a number of new organizations of TRAP transporter genes and proteins which suggest the recruitment of TRAP transporter components for use in other biological contexts.
#
# Review Abstract: Together blue television bag. Understand child fill point. Shake ask moment. Draw which organization significant beautiful need service. Leader heart deal data., Decision: Accepted, Date: 2022-09-01
# Paper Title: Integrating Locking and Optimistic Concurrency Control in Distributed Database Systems, Paper Abstract:

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def query_review_details():
    #sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/lab2")
    
    # Query for reviews and their authors
    query_authors = """
    PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>

    SELECT ?review ?abstract ?decision ?date ?authorName
    WHERE {
      # ?review a ex:Review;
              ex:abstract ?abstract;
              ex:date ?date;
              ex:decision ?decision;
              ex:reviewed_by ?author.
      # ?author foaf:name ?authorName.
    }
    """
    
    # Query for reviews and the papers they reviewed
    query_papers = """
    PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
    PREFIX ns1: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

    SELECT ?review ?abstract ?decision ?date ?paperTitle
    WHERE {
      # ?review a ex:Review;
              ex:abstract ?abstract;
              ex:date ?date;
              ex:decision ?decision;
              ex:reviewed_on ?paper.
      # ?paper ns1:title ?paperTitle.
    }
    """
    
    # Execute and print results for authors
    sparql.setQuery(query_authors)
    sparql.setReturnFormat(JSON)
    results_authors = sparql.query().convert()
    print("Reviews with Authors:")
    for result in results_authors["results"]["bindings"]:
        print(f'Review: {result["review"]["value"]}, Abstract: {result["abstract"]["value"]}, Decision: {result["decision"]["value"]}, Date: {result["date"]["value"]}, Author: {result["authorName"]["value"]}')
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_f561e25a-c3fe-4e88-bbd8-c1b4ba2d1c36, Abstract: Every fund evening speak Mrs. Father spend difference never. Next believe really enough. Happen out city region worry everything. Product fund discuss statement dog., Decision: Accepted, Date: 2022-03-19, Paper Title: BCI Promises in Emotional Involvement in Music and Games
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_f5d7cf64-2aad-4a99-a266-e0a852265b1d, Abstract: Tv last full present leader see. Reduce friend improve light property. Poor later majority list name respond who speech. Difference third stop member wish during. Ask rather ability at break total city. Wait rich performance give her right offer. Area now compare movement himself. Upon type still across., Decision: Rejected, Date: 2021-06-23, Paper Title: Predicting Student Self-regulation Strategies in Game-Based Learning Environments
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_f609fffc-9e8f-4806-a580-a4983958bd50, Abstract: Throughout moment until administration magazine perform international. Tax course pull do difficult. Record season enjoy., Decision: Accepted, Date: 2023-02-06, Paper Title: The Game of Triangles
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_f6388ff6-1035-4d9e-aae5-17d28dc567b3, Abstract: Chair on whatever each majority. Save old finally month cup despite. Wall letter better Democrat bill side throughout. Ago return adult then many land animal., Decision: Accepted, Date: 2024-01-13, Paper Title: O-Minimal Hybrid Reachability Games
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_fa6643e7-9b17-43ae-a4ff-f3ac8bb65434, Abstract: Sure always everything increase., Decision: Accepted, Date: 2024-03-01, Paper Title: Communities of Play: Emergent Cultures in Multiplayer Games and Virtual Worlds
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_fcb64934-f6bf-4ae8-8219-73d39a41dc5a, Abstract: Beautiful may serve return ability. Safe hundred result your number step. Their story perhaps meet life experience scientist., Decision: Rejected, Date: 2020-08-07, Paper Title: Natural language Interface for Database: A Brief review
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_fdd6613b-6dbe-47d3-b76a-799d40b4a9bf, Abstract: Yourself performance drug yourself run may best executive. Hundred while include part buy because. Structure seem art move travel. Summer control up garden need., Decision: Accepted, Date: 2019-09-27, Paper Title: Greedy and Linear Ensembles of Machine Learning Methods Outperform Single Approaches for QSPR Regression Problems
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_fdea8063-cb41-44b2-aeb2-896ec71a48ed, Abstract: Television paper threat season up. Now throw simply apply throw., Decision: Rejected, Date: 2023-01-02, Paper Title: Tripartite ATP-Independent Periplasmic Transporters: Application of a Relational Database for Genome-Wide Analysis of Transporter Gene Frequency and Organization
# Review: http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Review_ff16d596-9120-42e2-a464-c9941fae4500, Abstract: Together blue television bag. Understand child fill point. Shake ask moment. Draw which organization significant beautiful need service. Leader heart deal data., Decision: Accepted, Date: 2022-09-01, Paper Title: Integrating Locking and Optimistic Concurrency Control in Distributed Database Systems

# %% [markdown]
# Lets check journals

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def query_journals_and_linked_papers():
    #sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/lab2")
    
    # Query for all journal details
    query_journals = """
    PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>

    SELECT ?journal ?name ?volume ?year ?homepage
    WHERE {
      # ?journal a ex:Journal;
               ex:name ?name;
               ex:volume ?volume;
               ex:year ?year;
               foaf:homepage ?homepage.
    }
    """
    
    # Query for linking journals with papers
    query_journal_papers = """
    PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
    PREFIX ns1: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

    SELECT ?paperTitle ?journalName ?journalVolume ?journalYear
    WHERE {
      # ?journal a ex:Journal;
               ex:name ?journalName;
               ex:volume ?journalVolume;
               ex:year ?journalYear.
      # ?paper ns1:title ?paperTitle;
             ex:published_in ?journal.
    }
    """
    
    # Execute and print results for journals
    sparql.setQuery(query_journals)
    sparql.setReturnFormat(JSON)
    results_journals = sparql.query().convert()
    print("Journal Details:")
    for result in results_journals["results"]["bindings"]:
        print(f'Journal: {result["name"]["value"]}, Volume: {result["volume"]["value"]}, Year: {result["year"]["value"]}, Homepage: {result["homepage"]["value"]}')

    # Execute and print results for journal-linked papers
    sparql.setQuery(query_journal_papers)
    sparql.setReturnFormat(JSON)
    results_papers = sparql.query().convert()
    print("\nPapers and Their Journals:")
    for result in results_papers["results"]["bindings"]:
        print(f'Paper Title: {result["paperTitle"]["value"]}, Journal: {result["journalName"]["value"]}, Volume: {result["journalVolume"]["value"]}, Year: {result["journalYear"]["value"]}')

# Run the function to query GraphDB
query_journals_and_linked_papers()
# Out:
# Journal Details:
# Journal: Journal of Network and Systems Management, Volume: 3, Year: 1977, Homepage: https://link.springer.com/journal/10922
# Journal: International Journal of Financial Studies, Volume: 1, Year: 2004, Homepage: http://www.e-helvetica.nb.admin.ch/directAccess?callnumber=bel-281817
# Journal: Molecular Informatics, Volume: 3, Year: 1992, Homepage: http://onlinelibrary.wiley.com/journal/10.1002/(ISSN)1868-1751
# Journal: Molecular Informatics, Volume: 1, Year: 2007, Homepage: http://onlinelibrary.wiley.com/journal/10.1002/(ISSN)1868-1751
# Journal: Clinical Chemistry, Volume: 3, Year: 1996, Homepage: http://www.clinchem.org/
# Journal: Clinical Chemistry, Volume: 4, Year: 2001, Homepage: http://www.clinchem.org/
# Journal: Molecular Informatics, Volume: 2, Year: 2000, Homepage: http://onlinelibrary.wiley.com/journal/10.1002/(ISSN)1868-1751
# Journal: Journal of Chemical Information and Modeling, Volume: 7, Year: 1975, Homepage: http://pubs.acs.org/jcim
# Journal: International Journal of Pediatrics, Volume: 2, Year: 2015, Homepage: http://www.hindawi.com/journals/ijped/
# Journal: Journal of Network and Systems Management, Volume: 1, Year: 2014, Homepage: https://link.springer.com/journal/10922
# Journal: International Journal of Pediatrics, Volume: 3, Year: 1980, Homepage: http://www.hindawi.com/journals/ijped/
# Journal: Clinical Chemistry, Volume: 1, Year: 2018, Homepage: http://www.clinchem.org/
# Journal: Journal of Chemical Information and Modeling, Volume: 3, Year: 1984, Homepage: http://pubs.acs.org/jcim
# Journal: Journal of Chemical Information and Modeling, Volume: 4, Year: 2016, Homepage: http://pubs.acs.org/jcim
# Journal: Journal of Chemical Information and Modeling, Volume: 2, Year: 1982, Homepage: http://pubs.acs.org/jcim
# Journal: Journal of Chemical Information and Modeling, Volume: 1, Year: 1997, Homepage: http://pubs.acs.org/jcim
# Journal: Journal of Chemical Information and Modeling, Volume: 6, Year: 2015, Homepage: http://pubs.acs.org/jcim
# Journal: International Journal of Financial Studies, Volume: 3, Year: 1983, Homepage: http://www.e-helvetica.nb.admin.ch/directAccess?callnumber=bel-281817
# Journal: Clinical Chemistry, Volume: 2, Year: 2020, Homepage: http://www.clinchem.org/
# Journal: Journal of Chemical Information and Modeling, Volume: 3, Year: 1987, Homepage: http://pubs.acs.org/jcim
# Journal: International Journal of Pediatrics, Volume: 4, Year: 1994, Homepage: http://www.hindawi.com/journals/ijped/
# Journal: Journal of Chemical Information and Modeling, Volume: 1, Year: 1996, Homepage: http://pubs.acs.org/jcim
# Journal: International Journal of Financial Studies, Volume: 4, Year: 1993, Homepage: http://www.e-helvetica.nb.admin.ch/directAccess?callnumber=bel-281817
# Journal: Journal of Chemical Information and Modeling, Volume: 5, Year: 2021, Homepage: http://pubs.acs.org/jcim
# Journal: International Journal of Pediatrics, Volume: 1, Year: 1972, Homepage: http://www.hindawi.com/journals/ijped/
# Journal: Journal of Network and Systems Management, Volume: 2, Year: 1974, Homepage: https://link.springer.com/journal/10922
# Journal: Journal of Chemical Information and Modeling, Volume: 2, Year: 2019, Homepage: http://pubs.acs.org/jcim
# Journal: International Journal of Financial Studies, Volume: 2, Year: 1975, Homepage: http://www.e-helvetica.nb.admin.ch/directAccess?callnumber=bel-281817
#
# Papers and Their Journals:

# %% [markdown]
# ## B3. Create the final ontology

# %%
from rdflib import Graph

# List of Turtle files to combine
ttl_files = [
    "turtle/journals_enriched.ttl",
    "turtle/conferences_enriched.ttl",
    "turtle/papers_details_enriched.ttl",
    "turtle/citations.ttl",
    "turtle/review_on.ttl",
    "turtle/reviews.ttl",
    "turtle/reviewed_by.ttl",
    "turtle/published_in_enriched_v2.ttl",
    "turtle/affiliated_with.ttl",
    "turtle/affiliations.ttl",
    "turtle/written_by_enriched.ttl",
    "turtle/authors.ttl"
]

# Create an empty Graph
combined_graph = Graph()

# Load each file into the graph
for file_name in ttl_files:
    combined_graph.parse(file_name, format="ttl")

# Serialize and save the combined graph to an RDF/XML file
combined_graph.serialize(destination="combined_graph.rdf", format="xml")

print("All TTL files have been combined and saved as 'combined_graph.rdf'")
# Out:
# All TTL files have been combined and saved as 'combined_graph.rdf'

# %%
from rdflib import Graph, URIRef, RDF

# Load TBOX and ABOX
tbox = Graph().parse("p2-2.rdf", format='xml')
abox = Graph().parse("combined_graph.rdf", format='xml')

# Link instances to classes
for s, p, o in abox.triples((None, RDF.type, None)):
    class_uri = URIRef(f"http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#{o}")
    abox.set((s, RDF.type, class_uri))

# Merge TBOX and ABOX
combined_graph = tbox + abox
combined_graph.serialize(destination='final_ontology.rdf', format='pretty-xml')
# Out:
# <Graph identifier=N42d8b18ff31148f9af5baf5fa87240b8 (<class 'rdflib.graph.Graph'>)>

# %%
from rdflib import Graph, URIRef
from urllib.parse import urlparse

def is_valid_iri(iri):
    parsed = urlparse(iri)
    return all([parsed.scheme, parsed.netloc, parsed.path])

g = Graph()
g.parse("final_ontology.rdf", format="xml")

for s, p, o in g:
    for term in [s, p, o]:
        if isinstance(term, URIRef) and not is_valid_iri(str(term)):
            print(f"Invalid IRI found: {term}")

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
sparql = SPARQLWrapper("http://DESKTOP-GN9MFGC:7200/repositories/sdm-p2-2")
# Establish the connection to the SPARQL endpoint
#sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/bacaksiz")

# Queries

#Q1:
# PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>

# SELECT ?author 
# WHERE 
# {
#     ?author a ex:Author
# }

#Q2:

# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
# SELECT DISTINCT ?property 
# WHERE 
# { 
#     ?property rdfs:domain ex:Author .
# }


#Q3 -v1:

# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
# SELECT DISTINCT ?property 
# WHERE 
# {?property rdfs:domain ?domain . 
#   FILTER(?domain IN (ex:Conference, ex:Journal))
# }

#Q3 -v2:

# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

# SELECT DISTINCT ?property 
# WHERE 
# { 
#   ?property rdfs:domain ?domain .
#   ?domain rdfs:subClassOf ex:Proceeding .
# }



#Q4:


# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

# SELECT ?paper ?proceeding ?proceedingName
# WHERE { 
#             ?paper ex:written_by ?author .
#     		?author foaf:name ?authorName .
#     		FILTER(CONTAINS(LCASE(STR(?authorName)), "argasiński")).
#     		?paper ex:published_in ?proceeding .
#     		?proceeding ex:name ?proceedingName .
#     		FILTER(CONTAINS(LCASE(STR(?proceedingName)), "chemical")).
    		
#         }

# queries = {
#     "4Q1": "SELECT ?author WHERE { ?author a <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author> }",
#     "4Q2": "SELECT DISTINCT ?property WHERE { ?property <http://www.w3.org/2000/01/rdf-schema#domain> <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author> }",
#     "4Q3": "SELECT DISTINCT ?property WHERE { ?property <http://www.w3.org/2000/01/rdf-schema#domain> ?domain . FILTER(?domain IN (<http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Conference>, <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Journal>)) }",
#     "4Q4": """
#         SELECT ?paper ?title WHERE { 
#             ?paper a <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Paper> ;
#                    <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#written_by> <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#SampleAuthor> ;
#                    <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#published_in> ?proceeding .
#             ?proceeding a <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Proceeding> ;
#                         <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#conference_name> ?conferenceName .
#             FILTER(CONTAINS(LCASE(STR(?conferenceName)), "database"))
#         }
#         """
# }

queries = {
    "4Q1":  """PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
                PREFIX foaf: <http://xmlns.com/foaf/0.1/>

                SELECT ?author 
                WHERE 
                {
                    # ?author a ex:Author
                }""",
    "4Q2":  """
            PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
            PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
            SELECT DISTINCT ?property 
            WHERE 
            { 
                # ?property rdfs:domain ex:Author .
            }
          """,
    "4Q3":  """
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
            PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

            SELECT DISTINCT ?property 
            WHERE 
            { 
            # ?property rdfs:domain ?domain .
            # ?domain rdfs:subClassOf ex:Proceeding .
            }
          """,
    "4Q4":  """ 
            PREFIX foaf: <http://xmlns.com/foaf/0.1/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
            PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

            SELECT ?paper ?proceeding ?proceedingName
            WHERE { 
                        # ?paper ex:written_by ?author .
                        # ?author foaf:name ?authorName .
                        FILTER(CONTAINS(LCASE(STR(?authorName)), "argasiński")).
                        # ?paper ex:published_in ?proceeding .
                        # ?proceeding ex:name ?proceedingName .
                        FILTER(CONTAINS(LCASE(STR(?proceedingName)), "chemical")).
                        
                    }    
            """
}
    


# Execute each query and save the results to a text file
for key, query in queries.items():
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    with open(f"{key}.txt", "w") as file:
        for result in results["results"]["bindings"]:
            file.write(f"{result}\n")

print("All queries have been executed and results are saved.")
# Out:
# All queries have been executed and results are saved.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# Configuration
endpoint_url = "http://onur-MacBook-Pro.local:7200/repositories/bacaksiz"

# Initialize the SPARQL wrapper with your endpoint
sparql = SPARQLWrapper(endpoint_url)

def run_query(query):
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# Queries to fetch statistics
prefixes = """
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
"""

queries = {
    "Number of Classes": prefixes + "SELECT (COUNT(DISTINCT ?class) AS ?count) WHERE {[] a ?class.}",
    "Number of Properties": prefixes + "SELECT (COUNT(DISTINCT ?property) AS ?count) WHERE {[] ?property [].}",
    "Number of Instances for Main Classes": prefixes + """
        SELECT ?class (COUNT(?instance) AS ?count)
        WHERE {
            # ?instance a ?class.
            FILTER(?class IN (ex:Paper, ex:Author, ex:Affiliation, ex:Review, ex:Citation))
        }
        GROUP BY ?class
    """,
    "Total Number of Triples": prefixes + "SELECT (COUNT(*) AS ?count) WHERE { ?s ?p ?o. }"
}

# Run queries and print results
for description, query in queries.items():
    results = run_query(query)
    print(description)
    for result in results["results"]["bindings"]:
        class_label = result['class']['value'].split('#')[-1] if 'class' in result else 'Total'
        print(f"  {class_label}: {result['count']['value']}")
    print()
# Out:
# Number of Classes
#   Total: 18
#
# Number of Properties
#   Total: 37
#
# Number of Instances for Main Classes
#   Paper: 1566
#   Author: 518
#   Affiliation: 32
#   Review: 180
#
# Total Number of Triples
#   Total: 30218

# %%
import csv
from SPARQLWrapper import SPARQLWrapper, JSON

# Configure the endpoint
endpoint_url = "http://onur-MacBook-Pro.local:7200/repositories/bacaksiz"
sparql = SPARQLWrapper(endpoint_url)

# Define the SPARQL query
query = """
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>

SELECT ?author ?name
WHERE {
  # ?author a ex:Author .
  # ?author foaf:name ?name .
}
"""

# Set the query and format
sparql.setQuery(query)
sparql.setReturnFormat(JSON)

# Execute the query and process results
results = sparql.query().convert()

# Open a file for writing
with open('4.1.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Author URI', 'Name'])  # Writing the headers

    for result in results["results"]["bindings"]:
        author = result["author"]["value"]
        name = result["name"]["value"]
        writer.writerow([author, name])  # Writing each row

print("Results have been saved to '4.1.csv'.")
# Out:
# Results have been saved to '4.1.csv'.

# %% [markdown]
# 2. Find all properties whose domain is Author.

# %%
import csv
from SPARQLWrapper import SPARQLWrapper, JSON

# Configure the endpoint
endpoint_url = "http://onur-MacBook-Pro.local:7200/repositories/bacaksiz"
sparql = SPARQLWrapper(endpoint_url)

# Define the SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

SELECT DISTINCT ?property
WHERE {
  # ?property rdfs:domain ex:Author .
}
"""

# Set the query and format
sparql.setQuery(query)
sparql.setReturnFormat(JSON)

# Execute the query and process results
results = sparql.query().convert()

# Open a file for writing
with open('4.2.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Property'])  # Writing the headers

    for result in results["results"]["bindings"]:
        property = result["property"]["value"]
        writer.writerow([property])  # Writing each row

print("Results have been saved to '4.2.csv'.")
# Out:
# Results have been saved to '4.2.csv'.

# %% [markdown]
# 3. Find all properties whose domain is either Conference or Journal.

# %%
# Continue from the existing imports and setup
# Define the SPARQL query
query = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

SELECT ?proceeding 
WHERE {
  # ?proceeding a :Proceeding .
}

"""

# PREFIX : <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
# SELECT DISTINCT ?domain
# WHERE {
#   { ?domain a ex:Journal }
#   UNION
#   { ?domain a ex:Conference }
# }

# Set the query and format
sparql.setQuery(query)
sparql.setReturnFormat(JSON)

# Execute the query and process results
results = sparql.query().convert()

# Open a file for writing
with open('4.3.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Property'])  # Writing the headers

    for result in results["results"]["bindings"]:
        property = result["property"]["value"]
        writer.writerow([property])  # Writing each row

print("Results have been saved to '4.3.csv'.")
# Out:
# Results have been saved to '4.3.csv'.

# %% [markdown]
# 4. Find all the papers written by a given author that were published in database conferences. (Jim Brown)

# %%
# Continue from the existing imports and setup
# Define the SPARQL query
query = """
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>

SELECT DISTINCT ?paper ?title
WHERE {
  # ?paper ex:written_by ?author .
  # ?author foaf:name "Jim Brown" .
  # ?paper ex:published_in ?conference .
  # ?conference a ex:Conference .
  # ?conference ex:name ?confName .
  FILTER CONTAINS(LCASE(str(?confName)), "database")
}
"""

# Set the query and format
sparql.setQuery(query)
sparql.setReturnFormat(JSON)

# Execute the query and process results
results = sparql.query().convert()

# Open a file for writing
with open('4.4.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Paper URI', 'Title'])  # Writing the headers

    for result in results["results"]["bindings"]:
        paper = result["paper"]["value"]
        title = result["title"]["value"]
        writer.writerow([paper, title])  # Writing each row

print("Results have been saved to '4.4.csv'.")
# Out:
# Results have been saved to '4.4.csv'.

# %% [markdown]
# - 4.5 Authors with Most Publications Across Different Conferences and Journals
# - 4.6 Trend Analysis: Growth in Paper Publications Over Years by Topic

# %%
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON

# Initialize the SPARQL endpoint
sparql = SPARQLWrapper("http://onur-MacBook-Pro.local:7200/repositories/bacaksiz")

# Define the SPARQL queries
query1 = """
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>

SELECT ?authorName (COUNT(?paper) AS ?totalPapers)
WHERE {
  # ?paper ex:written_by ?author .
  # ?author foaf:name ?authorName .
}
GROUP BY ?authorName
ORDER BY DESC(?totalPapers)
LIMIT 10

"""

query2 = """
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?year (SAMPLE(?keyword) AS ?sampleKeyword) (COUNT(?paper) AS ?totalPapers)
WHERE {
  # ?paper ex:year ?year ;
         ex:keywords ?keywords .
  BIND(STRAFTER(?keywords, ",") AS ?keyword)  # Assuming keywords are separated by commas
}
GROUP BY ?year ?keyword
ORDER BY ?year

"""

def run_query(query):
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return pd.json_normalize(results['results']['bindings'])

# Execute the queries and save the results
df1 = run_query(query1)
df2 = run_query(query2)

# Print the results
print("Query 1 Results:")
print(df1)
print("\nQuery 2 Results:")
print(df2)

# Save the results to CSV
df1.to_csv('4.5.csv', index=False)
df2.to_csv('4.6.csv', index=False)
# Out:
# Query 1 Results:
#   authorName.type  authorName.value                      totalPapers.datatype  \
# 0         literal     A. Bensoussan  http://www.w3.org/2001/XMLSchema#integer
# 1         literal            S. Yam  http://www.w3.org/2001/XMLSchema#integer
# 2         literal  Bradford W. Mott  http://www.w3.org/2001/XMLSchema#integer
# 3         literal        N. Vieille  http://www.w3.org/2001/XMLSchema#integer
# 4         literal   James C. Lester  http://www.w3.org/2001/XMLSchema#integer
# 5         literal            Yu Bao  http://www.w3.org/2001/XMLSchema#integer
# 6         literal       Guosun Zeng  http://www.w3.org/2001/XMLSchema#integer
# 7         literal     Doina Caragea  http://www.w3.org/2001/XMLSchema#integer
# 8         literal        Xinming Ou  http://www.w3.org/2001/XMLSchema#integer
# 9         literal          Su Zhang  http://www.w3.org/2001/XMLSchema#integer
#
#   totalPapers.type totalPapers.value
# 0          literal                18
# 1          literal                18
# 2          literal                18
# 3          literal                18
# 4          literal                18
# 5          literal                 9
# 6          literal                 9
# 7          literal                 9
# 8          literal                 9
# 9          literal                 9
#
# Query 2 Results:
#                               year.datatype year.type year.value  \
# 0    http://www.w3.org/2001/XMLSchema#gYear   literal       1978
# 1    http://www.w3.org/2001/XMLSchema#gYear   literal       1986
# 2    http://www.w3.org/2001/XMLSchema#gYear   literal       1987
# 3    http://www.w3.org/2001/XMLSchema#gYear   literal       1987
# 4    http://www.w3.org/2001/XMLSchema#gYear   literal       1988
# ..                                      ...       ...        ...
# 142  http://www.w3.org/2001/XMLSchema#gYear   literal       2022
# 143  http://www.w3.org/2001/XMLSchema#gYear   literal       2022
# 144  http://www.w3.org/2001/XMLSchema#gYear   literal       2022
# 145  http://www.w3.org/2001/XMLSchema#gYear   literal       2022
# 146  http://www.w3.org/2001/XMLSchema#gYear   literal       2023
#
#     sampleKeyword.type                                sampleKeyword.value  \
# 0              literal
# 1              literal
# 2              literal  main,database,systems,performance,recovery,dec...
# 3              literal  learning,team,problems,elements,competition,co...
# 4              literal  semantics,dataloga,logic,updates,datalog,w,p,s...
# ..                 ...                                                ...
# 142            literal  structure,predictions,alphafold,arguably,year,...
# 143            literal  fake,knowledge,media,detection,social,due,help...
# 144            literal  databases,update,pruw,submodel,problem,given,c...
# 145            literal  radar,restroom,using,system,behaviors,doppler,...
# 146            literal  financial,machine,deep,algorithms,models,price...
#
#                          totalPapers.datatype totalPapers.type  \
# 0    http://www.w3.org/2001/XMLSchema#integer          literal
# 1    http://www.w3.org/2001/XMLSchema#integer          literal
# 2    http://www.w3.org/2001/XMLSchema#integer          literal
# 3    http://www.w3.org/2001/XMLSchema#integer          literal
# 4    http://www.w3.org/2001/XMLSchema#integer          literal
# ..                                        ...              ...
# 142  http://www.w3.org/2001/XMLSchema#integer          literal
# 143  http://www.w3.org/2001/XMLSchema#integer          literal
# 144  http://www.w3.org/2001/XMLSchema#integer          literal
# 145  http://www.w3.org/2001/XMLSchema#integer          literal
# 146  http://www.w3.org/2001/XMLSchema#integer          literal
#
#     totalPapers.value
# 0                   9
# 1                   9
# 2                   9
# 3                   9
# 4                   9
# ..                ...
# 142                 9
# 143                 9
# 144                 9
# 145                 9
# 146                 9
#
# [147 rows x 8 columns]
